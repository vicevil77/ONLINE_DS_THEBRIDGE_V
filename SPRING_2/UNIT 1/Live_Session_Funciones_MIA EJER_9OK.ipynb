# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Funciones: Recursividad
# Una función se puede llamar a si misma en la propia declaración, como si de un bucle se tratase. Es un concepto algo complejo, pero elegante a la hora de implementar nuestros programas. La única parte negativa es que cuesta un poco comprender qué es lo que hace la función. Como todo, tiene sus ventajas y sus inconvenientes.
#
# Calculemos el factorial de un numero *n!*

# %% [markdown]
# ![factorial.png](attachment:factorial.png)

# %%
def argumento

# %%
# Lo podriamos calcular con un bucle
num_factorial = 3

output = 1
for i in range(num_factorial):
    output = output * (i + 1)
    print()
    print(i + 1)
print(output)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# O mediante una funcion recursiva
def factorial(x):
    if x == 1:
        return 1
    else:
        return (x * factorial(x-1))


num_factorial = 3
print("El factorial de", num_factorial, "es", factorial(num_factorial ))

"""primera vez que llamo a la funcion:
x = num:factorial = 3
if 3 ==1: -> False
llamo a la funcion otra vez pero con argumento x -1 =2
hago x *2 
retorno x *1
retorno x*1 


2 segunda vez que llamo a la funcion otra vez pero con argumento
x=2
if 2 ==1 '>false'
    llamo otra vez: argumento x -1 =1



tercera vez que llamo a la funcion otra vez pero con argumento
x =1
if 1 ==1 ->True
retorna
"""

# %% [markdown]
# ![recursivity.jpg](attachment:recursivity.jpg)

# %% [markdown]
# La recursividad termina cuando se alcanza el caso base (en este ejemplo, cuando n=0) o caso de parada. Es crucial tener un caso base o de parada en funciones recursivas para evitar llamadas infinitas y, por lo tanto, un error de desbordamiento de la pila (stack overflow) y que se bloquee nuestro programa.

# %% [markdown]
# [Ejemplo paso a paso de cómo se calcula un factorial mediante funciones recursivas](https://www.programiz.com/python-programming/recursion#:~:text=Following%20is%20an%20example%20of,*5*6%20%3D%20720%20.)

# %% [markdown]
# ## Documentar funciones
# Como ya vimos en el primer Notebook, hay que documentar el código en la medida de lo posible. En particular, es necesario documentar bien las funciones. porque muchas veces las importamos de otro sitio, las usamos porque funcionan, pero no sabemos muy bien que hacen. Es por ello, que en Python existe un atributo dentro de las funciones, módulos, métodos o clases, que permite acceder a "sus comentarios", a su documentación, donde nos indica qué es lo que hace.
#
# Este atributo especial se llama *docstring*, y se accede mediante `nombre_funcion.__doc__`

# %%
def multiplica(x,y):
    """
    Funcion que multiplca los dos argumentos: x*y
    Inputs:
        x: float
        y: float
    
    Output:
        x * y: float
    """
    print("Empieza la funcion")
    # Mas comentarios
    
    return x*y

print(multiplica(2,2))
print(multiplica.__doc__)

# %% [markdown]
# Los comentarios que se ponen pueden ser de línea o multilínea. Para funciones sencillas puede ser suficiente con una sola línea de comentario, pero si fuesen más complejas, el *docstring* debería llevar la siguiente información:
# * Descripción de la función
# * Argumentos de entrada: nombre, tipos y qué es lo que hacen
# * Argumentos de salida: nombre, tipos y qué son

# %% [markdown]
# ## Resumen Funciones

# %%
# Una funcion tiene la siguiente sintaxis
def km_millas(distancia):
    millas = distancia * 0.62
    return millas

# La podemos llamar cuántas veces queramos
print(km_millas(2))
print(km_millas(5))
print(km_millas(10))

# Las funciones pueden tener argumentos posicionales
def multipl(x1, x2, x3, x4):
    return (x1 * x2 * x3) / x4

multipl(4,6,7,2)

# Argumentos variables
def multipl_var(*args):
    print(type(args))
    mult_tot = 1
    
    for i in args:
        mult_tot = mult_tot * i
        
    return mult_tot


multipl_var(4,5,6,3)


# Argumentos con formato clave valor
def movil(**kwargs):
    
    print(type(kwargs))
    for key, value in kwargs.items():
        print(key, "=", value)
        
    return kwargs

# Llamamos a la funcion
print(movil(Camara = "24MPx",
           Bateria = 10,
           Peso = 200))


# Argumentos keyword
def venta_online(pedido, fecha_entrega, incidencia = False):
    
    if(incidencia):
        print("Contacte con Att. Cliente")
        
    else:
        print("Su pedido", pedido, "se entregará el", fecha_entrega)
        
venta_online("AAA", "20-07-2020")
venta_online("AAA", "20-07-2020", True)



# Las funciones se documentan con el atributo docstring
def multiplica(x,y):
    """
    Funcion que multiplca los dos argumentos: x*y
    """
    print("Empieza la funcion")
    # Mas comentarios
    
    return x*y

print(multiplica(2,2))
print(multiplica.__doc__)

# %% [markdown]
# Escribe un programa que obtenga el n-ésimo número de la [serie de Fibonacci](https://es.wikipedia.org/wiki/Sucesi%C3%B3n_de_Fibonacci). Tienes que crear una función recursiva con un único argumento.
#
# ```Python
# fibonacci(2) = 1
# fibonacci(4) = 3
# fibonacci(5) = 5
# fibonacci(8) = 21

# %%
def fibonacci(numero):
    """La serie de Fibonacci es una secuencia matemática infinita de números 
    en la que cada número después de los dos primeros (0 y 1) 
    es la suma de los dos números precedentesF(0) = 0:
        F(0) = 0
        F(1) = 1
        F(n) = F(n-1) + F(n-2) para n > 1"""
    if numero == 0:
        print(0)
    elif numero ==1:
        print(1)
    elif numero >1:
        print((numero - 1) + (numero -2))

# %%
#ingreso los datos para la serie:
numero = float(input("introduce un numero para calcular la serie de fibonacci:" ))
#llamada a la funcion 
def fibonacci(numero):
    """La serie de Fibonacci es una secuencia matemática infinita de números 
    en la que cada número después de los dos primeros (0 y 1) 
    es la suma de los dos números precedentesF(0) = 0:
        F(0) = 0
        F(1) = 1
        F(n) = F(n-1) + F(n-2) para n > 1"""
    if numero == 0:
        return 0
    elif numero ==1:
        return 1
    elif numero >1:
        return (numero - 1) + (numero -2)
#muestra resultado
print(f"la serie de fibonacci teniendo en cuenta el {numero} elegido es {fibonacci(numero)}")
# Out:
# la serie de fibonacci teniendo en cuenta el 4.5 elegido es 6.0

# %% [markdown]
# ## Ejercicio 9
# Define en una única celda las siguientes funciones:
# * Función que calcule el área de un cuadrado
# * Función que calcule el area de un triángulo
# * Función que calcule el área de un círculo
#
# En otra celda, calcular el area de:
# * Dos círculos de radio 10 + un triángulo de base 3 y altura 7
# * Un cuadrado de lado = 10 + 3 círculos (uno de radio = 4 y los otros dos de radio = 6) + 5 triángulos de base = 2 + altura = 4

# %%
def area_cuadradado(xb,yh):
    """funcion que calcula el area de un cuadrdo
    2 argumentos: xb = base e yh = altura
    outputs: A = BxA """
    Area = xb * yh
    return Area 

def area_triangulo (xb, yh):
    """funcion que calcula el area de un triangulo
    2 argumentos: xb = base e yh = altura
    outputs: A = (BxA)/2 """
    Area = (xb*yh)/2
    return Area

def area_circulo(radio):    
    import math
    """funcion que calcula el area de un circulo
    1 argumentos: r = radio y la constante Pi
    outputs: A= Pi*r2 """
    Area = math.pi*radio**2
    return Area

# %%
import math
#ingresa radio circulo
radio = float(input("Ingresa el radio del primer círculo: "))
radio = float(input("Ingresa el radio del segundo círculo: "))
# llama a la funcion  
def area_circulo(radio):    
    import math
    """funcion que calcula el area de un circulo
    1 argumentos: r = radio y la constante Pi
    outputs: A= Pi*r2 """
    Area = math.pi*radio**2
    return Area
#muestra resultado
print(f"El área del primer y segundo círculo con radio comun {radio} es: {area_circulo(radio)} y {area_circulo(radio)}")
#ingresa los valores base y altura del triangulo
xb = float(input("Ingresa el la base del triangulo: "))
yh = float(input("Ingresa el la altura del triangulo: "))
# llama a la funcion 
def area_triangulo (xb, yh):
    """funcion que calcula el area de un triangulo
    2 argumentos: xb = base e yh = altura
    outputs: A = (BxA)/2 """
    Area = (xb*yh)/2
    return Area
#muestra resultado
print(f"El área del triangulo con base {xb} y altura {yh} es: {area_triangulo (xb, yh)}")

#suma de las tres  areas
Suma_total =  area_circulo(radio) + area_circulo(radio) + area_triangulo (xb, yh)
print(f"la suma total deel area de los dos circulos y el triangulo es: {Suma_total}")

#ingresa base y altura del cuadrado
xb = float(input("Ingresa el la base del cuadrado: "))
yh = float(input("Ingresa el la altura del cuadrado: "))
# llama a la funcion 
def area_cuadradado(xb,yh):
    """funcion que calcula el area de un cuadrdo
    2 argumentos: xb = base e yh = altura
    outputs: A = BxA """
    Area = xb * yh
    return Area 
#muestra resultado
print(f"El área del cuadrdado conn base {xb} y altura {yh} es: {area_cuadradado(xb,yh)}")
#ingresa radio nuevos circulos
radio = float(input("Ingresa el radio del primer círculo: "))
radio = float(input("Ingresa el radio del segundo círculo: "))
radio = float(input("Ingresa el radio del tercer círculo: "))
# llama a la funcion  
def area_circulo(radio):    
    import math
    """funcion que calcula el area de un circulo
    1 argumentos: r = radio y la constante Pi
    outputs: A= Pi*r2 """
    Area = math.pi*radio**2
    return Area
#muestra resultado
print(f"El área del primer, segundo y tercer círculo, dos con radio comun {radio} y otro con {radio} es: {area_circulo(radio)} {area_circulo(radio)} y {area_circulo(radio)}")

#ingresa los valores base y altura de 5  triangulos con misma xb e yh
xb = float(input("Ingresa el la base del triangulo: "))
yh = float(input("Ingresa el la altura del triangulo: "))

# llama a la funcion 
def area_triangulo (xb, yh):
    """funcion que calcula el area de un triangulo
    2 argumentos: xb = base e yh = altura
    outputs: A = (BxA)/2 """
    Area = (xb*yh)/2
    return Area
#muestra resultado
print(f"El área de los  cinco triangulos con base {xb} y altura {yh} es, de manera individual cada uno es de {area_triangulo (xb, yh)} y de forma colectiva {area_triangulo (xb, yh)*5}")

Suma_total =  area_cuadradado(xb,yh) + 3*area_circulo(radio) + 5*area_triangulo (xb, yh)
print(f"la suma total del area del cuadrado mas los tres circulos y  cinco triangulos es: {Suma_total}")
# Out:
# El área del primer y segundo círculo con radio comun 10.0 es: 314.1592653589793 y 314.1592653589793
# El área del triangulo con base 3.0 y altura 7.0 es: 10.5
# la suma total deel area de los dos circulos y el triangulo es: 638.8185307179587
# El área del cuadrdado conn base 10.0 y altura 10.0 es: 100.0
# El área del primer, segundo y tercer círculo, dos con radio comun 6.0 y otro con 6.0 es: 113.09733552923255 113.09733552923255 y 113.09733552923255
# El área de los  cinco triangulos con base 2.0 y altura 4.0 es, de manera individual cada uno es de 4.0 y de forma colectiva 20.0
# la suma total del area deñ cuadrado mas los tres circulos y  cinco triangulos es: 367.29200658769764
