# %%
import os
import tensorflow as tf

# Configurar la GPU antes de inicializar TensorFlow
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)
os.environ["KERAS_BACKEND"] = "tensorflow"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import funciones_ML as bt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay,classification_report,r2_score,RocCurveDisplay
from sklearn.linear_model import LogisticRegression, LinearRegression, Ridge, Lasso, ElasticNet, SGDRegressor, SGDClassifier, RidgeClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.svm import SVC, SVR



# Configurar pandas para mostrar todas las filas y columnas
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
#pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)


# Código para los tamaños de las fuentes y los "ticks" de los ejes:
plt.rc('font', size=6)
plt.rc('axes', labelsize=10, titlesize=10)
plt.rc('legend', fontsize=10)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %%
df_1=pd.read_csv("/media/vicevil/Nuevo vol/Cursos/REPOSITORIOS/DATASET/malware_total/original/CTU-IoT-Malware-Capture-1-1conn.log.labeled.csv", sep="|")

# %%
df_1.shape
# Out:
# (1008748, 23)

# %%
df_1.head(2)
# Out:
#              ts                 uid        id.orig_h  id.orig_p  \
# 0 1,525,879,831  CUmrqr4svHuSXJy5z7  192.168.100.103     51,524
# 1 1,525,879,831  CH98aB3s1kJeq6SFOc  192.168.100.103     56,305
#
#         id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0  65.127.233.163         23   tcp       -  2.999051          0  ...
# 1   63.150.16.171         23   tcp       -         -          -  ...
#
#   local_resp missed_bytes history orig_pkts  orig_ip_bytes resp_pkts  \
# 0          -            0       S         3            180         0
# 1          -            0       S         1             60         0
#
#    resp_ip_bytes  tunnel_parents      label             detailed-label
# 0              0               -  Malicious  PartOfAHorizontalPortScan
# 1              0               -  Malicious  PartOfAHorizontalPortScan
#
# [2 rows x 23 columns]

# %%
df_2=pd.read_csv("/media/vicevil/Nuevo vol/Cursos/REPOSITORIOS/DATASET/malware_total/original/CTU-IoT-Malware-Capture-3-1conn.log.labeled.csv", sep="|")

# %%
df_2.shape
# Out:
# (156103, 23)

# %%
df_3=pd.read_csv("/media/vicevil/Nuevo vol/Cursos/REPOSITORIOS/DATASET/malware_total/original/CTU-IoT-Malware-Capture-8-1conn.log.labeled.csv", sep="|")

# %%
df_3.shape
# Out:
# (10403, 23)

# %%
df_4=pd.read_csv("/media/vicevil/Nuevo vol/Cursos/REPOSITORIOS/DATASET/malware_total/original/CTU-IoT-Malware-Capture-9-1conn.log.labeled.csv", sep="|")

# %%
df_4.shape
# Out:
# (6378293, 23)

# %%
df_5=pd.read_csv("/media/vicevil/Nuevo vol/Cursos/REPOSITORIOS/DATASET/malware_total/original/CTU-IoT-Malware-Capture-20-1conn.log.labeled.csv", sep="|")

# %%
df_5.shape
# Out:
# (3209, 23)

# %%
df_6=pd.read_csv("/media/vicevil/Nuevo vol/Cursos/REPOSITORIOS/DATASET/malware_total/original/CTU-IoT-Malware-Capture-21-1conn.log.labeled.csv", sep="|")

# %%
df_6.shape
# Out:
# (3286, 23)

# %%
df_7=pd.read_csv("/media/vicevil/Nuevo vol/Cursos/REPOSITORIOS/DATASET/malware_total/original/CTU-IoT-Malware-Capture-34-1conn.log.labeled.csv", sep="|")

# %%
df_7.shape
# Out:
# (23145, 23)

# %%
df_8=pd.read_csv("/media/vicevil/Nuevo vol/Cursos/REPOSITORIOS/DATASET/malware_total/original/CTU-IoT-Malware-Capture-35-1conn.log.labeled.csv", sep="|")

# %%
df_8.shape
# Out:
# (10447787, 23)

# %%
df_9=pd.read_csv("/media/vicevil/Nuevo vol/Cursos/REPOSITORIOS/DATASET/malware_total/original/CTU-IoT-Malware-Capture-42-1conn.log.labeled.csv", sep="|")

# %%
df_9.shape
# Out:
# (4426, 23)

# %%
df_10=pd.read_csv("/media/vicevil/Nuevo vol/Cursos/REPOSITORIOS/DATASET/malware_total/original/CTU-IoT-Malware-Capture-44-1conn.log.labeled.csv", sep="|")

# %%
df_10.shape
# Out:
# (237, 23)

# %%
df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ts              237 non-null    float64
#  1   uid             237 non-null    object
#  2   id.orig_h       237 non-null    object
#  3   id.orig_p       237 non-null    int64
#  4   id.resp_h       237 non-null    object
#  5   id.resp_p       237 non-null    int64
#  6   proto           237 non-null    object
#  7   service         237 non-null    object
#  8   duration        237 non-null    object
#  9   orig_bytes      237 non-null    object
#  10  resp_bytes      237 non-null    object
#  11  conn_state      237 non-null    object
#  12  local_orig      237 non-null    object
#  13  local_resp      237 non-null    object
#  14  missed_bytes    237 non-null    int64
#  15  history         237 non-null    object
#  16  orig_pkts       237 non-null    int64
#  17  orig_ip_bytes   237 non-null    int64
#  18  resp_pkts       237 non-null    int64
#  19  resp_ip_bytes   237 non-null    int64
#  20  tunnel_parents  237 non-null    object
#  21  label           237 non-null    object
#  22  detailed-label  222 non-null    object
# dtypes: float64(1), int64(7), object(15)
# memory usage: 42.7+ KB

# %%
df_11=pd.read_csv("/media/vicevil/Nuevo vol/Cursos/REPOSITORIOS/DATASET/malware_total/original/CTU-IoT-Malware-Capture-48-1conn.log.labeled.csv", sep="|")
# Out:
# /home/vicevil/miniconda3/envs/tf-gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (8,9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_11.shape
# Out:
# (3394338, 23)

# %%
df_12=pd.read_csv("/media/vicevil/Nuevo vol/Cursos/REPOSITORIOS/DATASET/malware_total/original/CTU-IoT-Malware-Capture-60-1conn.log.labeled.csv", sep="|")

# %%
df_12.shape
# Out:
# (3581028, 23)

# %%
#total de regist5ros de los 12 df antes del dropna y quitar guione
"24002255"
# Out:
# '24002255'

# %%
lista=[df_1, df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10,df_11,df_12]

# %%
#vamos a buscar los nuelos de tos antes de juntarlos
for i, df in enumerate(lista):
  print(f"df_{i+1}:")
  print(df.isnull().sum().sum(), "valores nulos")
  print()
# Out:
# df_1:
# 0 valores nulos
#
# df_2:
# 0 valores nulos
#
# df_3:
# 0 valores nulos
#
# df_4:
# 0 valores nulos
#
# df_5:
# 0 valores nulos
#
# df_6:
# 0 valores nulos
#
# df_7:
# 21222 valores nulos
#
# df_8:
# 2185386 valores nulos
#
# df_9:
# 3 valores nulos
#
# df_10:
# 15 valores nulos
#
# df_11:
# 3388871 valores nulos
#
# df_12:
# 3578457 valores nulos

# %%
#ahopra vamos a contar los giones "-"
for i, df in enumerate(lista):
    print(f"df_{i+1}:")
    total_guiones = df.apply(lambda x: x.astype(str).str.count("-")).sum().sum()
    print(total_guiones, "guiones")
    print()
# Out:
# df_1:
# 6907347 guiones
#
# df_2:
# 846079 guiones
#
# df_3:
# 62348 guiones
#
# df_4:
# 44622206 guiones
#
# df_5:
# 18092 guiones
#
# df_6:
# 17976 guiones
#
# df_7:
# 146128 guiones
#
# df_8:
# 63351494 guiones
#
# df_9:
# 23384 guiones
#
# df_10:
# 1391 guiones
#
# df_11:
# 15231966 guiones
#
# df_12:
# 25067799 guiones

# %% [markdown]
# #### vamos a mira el 8 el 11 u 12 respecto a los nulos

# %% [markdown]
# todas tenian nulos en la columna detailed-label, pero al convertir los guines en NaN y hacer dropna ya no tienen

# %%
for i, df in enumerate(lista):
  print(f"df_{i+1}:")
  print(df["label"].unique(), "valores unicos")
  print()
# Out:
# df_1:
# ['Malicious' 'Benign'] valores unicos
#
# df_2:
# ['Malicious' 'Benign'] valores unicos
#
# df_3:
# ['Benign' 'Malicious'] valores unicos
#
# df_4:
# ['Benign' 'Malicious'] valores unicos
#
# df_5:
# ['Benign' 'Malicious   C&C'] valores unicos
#
# df_6:
# ['Benign' 'Malicious   C&C'] valores unicos
#
# df_7:
# ['Benign' 'Malicious   C&C' 'Malicious   PartOfAHorizontalPortScan'
#  'Malicious   DDoS'] valores unicos
#
# df_8:
# ['Malicious   C&C' 'Benign' 'Malicious   Attack' 'Malicious   DDoS'] valores unicos
#
# df_9:
# ['Malicious   FileDownload' 'Malicious   C&C' 'Benign'] valores unicos
#
# df_10:
# ['Malicious   C&C' 'Benign' 'Malicious   DDoS'] valores unicos
#
# df_11:
# ['Malicious   C&C' 'Malicious   PartOfAHorizontalPortScan'
#  'Malicious   Attack' 'Benign'] valores unicos
#
# df_12:
# ['Benign' 'Malicious   C&C' 'Malicious   DDoS'] valores unicos

# %%
for i, df in enumerate(lista):
  print(f"df_{i+1}:")
  print(df["detailed-label"].unique(), "valores unicos")
  print()
# Out:
# df_1:
# ['PartOfAHorizontalPortScan' '-' 'C&C'] valores unicos
#
# df_2:
# ['PartOfAHorizontalPortScan' '-' 'C&C' 'Attack'] valores unicos
#
# df_3:
# ['-' 'C&C'] valores unicos
#
# df_4:
# ['-' 'PartOfAHorizontalPortScan'] valores unicos
#
# df_5:
# ['-' 'Torii'] valores unicos
#
# df_6:
# ['-' 'Torii'] valores unicos
#
# df_7:
# ['-' nan] valores unicos
#
# df_8:
# [nan '-' 'FileDownload'] valores unicos
#
# df_9:
# [nan 'FileDownload' '-'] valores unicos
#
# df_10:
# ['FileDownload' nan '-'] valores unicos
#
# df_11:
# ['HeartBeat' nan '-' 'PartOfAHorizontalPortScan'] valores unicos
#
# df_12:
# ['-' 'HeartBeat' nan] valores unicos

# %% [markdown]
# El Dataset de mas arriba es uno de los 12 que he juntado para hacer el dataset malware bytes , habiendo 6 columnnas de mas ya que de la columna original ts he extraido los valores del tiempo: time_clok, interval_time, anyo, month y day_week

# %%
for i, df in enumerate(lista):
  print(f"df_{i+1}:")
  print(len(df), "suma valores despues del dropna")
  print()
# Out:
# df_1:
# 1008748 suma valores despues del dropna
#
# df_2:
# 156103 suma valores despues del dropna
#
# df_3:
# 10403 suma valores despues del dropna
#
# df_4:
# 6378293 suma valores despues del dropna
#
# df_5:
# 3209 suma valores despues del dropna
#
# df_6:
# 3286 suma valores despues del dropna
#
# df_7:
# 23145 suma valores despues del dropna
#
# df_8:
# 10447787 suma valores despues del dropna
#
# df_9:
# 4426 suma valores despues del dropna
#
# df_10:
# 237 suma valores despues del dropna
#
# df_11:
# 3394338 suma valores despues del dropna
#
# df_12:
# 3581028 suma valores despues del dropna

# %%
#suma total despues del dropna
Total_despues=15837049

# %%
#diferencia entre antes y el despues
total_antes= 24002255

# %%
diferencia= total_antes-Total_despues
porcentaje= diferencia*100/total_antes
print(diferencia, porcentaje)
# Out:
# 8165206 34.01849534554149

# %% [markdown]
# UNIMOS EN 1 EL DATASET COMPLETO SIN nAn NI GIUINES, PERDIENDO UN 34% DE INFORMACION PERO NOS QUEDAMOS CON CASI 16000000 DE DATOS EN 23 COLUMNAS

# %%
df_malware= pd.concat(lista, axis=0)

# %%
df_malware
# Out:
#                    ts                 uid        id.orig_h  id.orig_p  \
# 0        1.525880e+09  CUmrqr4svHuSXJy5z7  192.168.100.103    51524.0
# 1        1.525880e+09  CH98aB3s1kJeq6SFOc  192.168.100.103    56305.0
# 2        1.525880e+09   C3GBTkINvXNjVGtN5  192.168.100.103    41101.0
# 3        1.525880e+09   CDe43c1PtgynajGI6  192.168.100.103    60905.0
# 4        1.525880e+09  CJaDcG3MZzvf1YVYI4  192.168.100.103    44301.0
# ...               ...                 ...              ...        ...
# 3581023  1.569026e+09   CyeWQ7K6jWDDbI4Kd    192.168.1.195      123.0
# 3581024  1.568941e+09  CS9u9p3IiuKuTYfauc    192.168.1.195    37306.0
# 3581025  1.569026e+09   ChLFLFZumxpFdFbV8    192.168.1.195      123.0
# 3581026  1.569026e+09  CdOxuh15kV4eHJYKkb    192.168.1.195      123.0
# 3581027  1.569026e+09   C7q9EgOTCtbdacBK3    192.168.1.195      123.0
#
#                id.resp_h  id.resp_p proto service      duration orig_bytes  \
# 0         65.127.233.163       23.0   tcp       -      2.999051          0
# 1          63.150.16.171       23.0   tcp       -             -          -
# 2           111.40.23.49       23.0   tcp       -             -          -
# 3        131.174.215.147       23.0   tcp       -      2.998796          0
# 4            91.42.47.63       23.0   tcp       -             -          -
# ...                  ...        ...   ...     ...           ...        ...
# 3581023   89.221.210.188      123.0   udp       -      0.004499         96
# 3581024    102.165.48.81    17769.0   tcp       -  84970.742165       8523
# 3581025   212.111.30.190      123.0   udp       -      0.007994         96
# 3581026       5.1.56.123      123.0   udp       -      0.005250         96
# 3581027      81.2.254.32      123.0   udp       -      0.005497         96
#
#          ... local_resp missed_bytes  history orig_pkts  orig_ip_bytes  \
# 0        ...          -          0.0        S       3.0          180.0
# 1        ...          -          0.0        S       1.0           60.0
# 2        ...          -          0.0        S       1.0           60.0
# 3        ...          -          0.0        S       3.0          180.0
# 4        ...          -          0.0        S       1.0           60.0
# ...      ...        ...          ...      ...       ...            ...
# 3581023  ...          -          0.0       Dd       2.0          152.0
# 3581024  ...          -          0.0  ShAdDaT    8952.0       483602.0
# 3581025  ...          -          0.0       Dd       2.0          152.0
# 3581026  ...          -          0.0       Dd       2.0          152.0
# 3581027  ...          -          0.0       Dd       2.0          152.0
#
#         resp_pkts  resp_ip_bytes  tunnel_parents            label  \
# 0             0.0            0.0               -        Malicious
# 1             0.0            0.0               -        Malicious
# 2             0.0            0.0               -        Malicious
# 3             0.0            0.0               -        Malicious
# 4             0.0            0.0               -        Malicious
# ...           ...            ...             ...              ...
# 3581023       2.0          152.0               -           Benign
# 3581024    9613.0       520116.0               -  Malicious   C&C
# 3581025       2.0          152.0               -           Benign
# 3581026       2.0          152.0               -           Benign
# 3581027       2.0          152.0               -           Benign
#
#                     detailed-label
# 0        PartOfAHorizontalPortScan
# 1        PartOfAHorizontalPortScan
# 2        PartOfAHorizontalPortScan
# 3        PartOfAHorizontalPortScan
# 4        PartOfAHorizontalPortScan
# ...                            ...
# 3581023                          -
# 3581024                  HeartBeat
# 3581025                          -
# 3581026                          -
# 3581027                          -
#
# [25011003 rows x 23 columns]

# %%
df_malware.replace("-", np.nan, inplace=True)
# Configurar la opción de formato de punto flotante para mostrar NaN
pd.options.display.float_format = '{:,.0f}'.format

# %%
df_malware.isna().sum()
# Out:
# ts                   0
# uid                  0
# id.orig_h            0
# id.orig_p            0
# id.resp_h            0
# id.resp_p            0
# proto                0
# conn_state           0
# missed_bytes         0
# history          25116
# orig_pkts            0
# orig_ip_bytes        0
# resp_pkts            0
# resp_ip_bytes        0
# label                0
# anyo                 0
# mes                  0
# dia                  0
# hora                 0
# dia_semanal          0
# dtype: int64

# %%
#debido a la gran cantidad de nulos, me cargo varias columnas : ["service", "duration", orig_bytes","resp_bytes",local_orig", "local_resp","tunnel_parents", "detailed_label"]
df_malware.drop(columns={"service", "duration", "orig_bytes","resp_bytes","local_orig", "local_resp","tunnel_parents", "detailed-label"}, inplace=True)

# %%
#bt.obtener_estadisticas(df_malware)

# %%
df_malware.ts
# Out:
# 0         1,525,879,831
# 1         1,525,879,831
# 2         1,525,879,831
# 3         1,525,879,832
# 4         1,525,879,832
#                ...
# 3581023   1,569,025,924
# 3581024   1,568,941,445
# 3581025   1,569,026,391
# 3581026   1,569,026,380
# 3581027   1,569,026,383
# Name: ts, Length: 25011003, dtype: float64

# %%
#convierto de horario unix a datetime
df_malware['ts'] = pd.to_datetime(df_malware['ts'], unit='s')
df_malware.ts.unique()
# Out:
# array(['2018-05-09T15:30:31.015811072', '2018-05-09T15:30:31.025054976',
#        '2018-05-09T15:30:31.045044992', ...,
#        '2019-09-21T00:39:50.773122048', '2019-09-21T00:39:39.773117184',
#        '2019-09-21T00:39:42.773051904'], dtype='datetime64[ns]')

# %%
#separo columnas de tiempos
df_malware["anyo"] = df_malware["ts"].dt.year
df_malware["mes"] = df_malware["ts"].dt.month
df_malware["dia"] = df_malware["ts"].dt.day
df_malware["hora"] = df_malware["ts"].dt.hour
df_malware["dia_semanal"]= df_malware["ts"].dt.dayofweek

# %%
df_malware
# Out:
#                         uid        id.orig_h  id.orig_p        id.resp_h  \
# 0        CUmrqr4svHuSXJy5z7  192.168.100.103     51,524   65.127.233.163
# 1        CH98aB3s1kJeq6SFOc  192.168.100.103     56,305    63.150.16.171
# 2         C3GBTkINvXNjVGtN5  192.168.100.103     41,101     111.40.23.49
# 3         CDe43c1PtgynajGI6  192.168.100.103     60,905  131.174.215.147
# 4        CJaDcG3MZzvf1YVYI4  192.168.100.103     44,301      91.42.47.63
# ...                     ...              ...        ...              ...
# 3581023   CyeWQ7K6jWDDbI4Kd    192.168.1.195        123   89.221.210.188
# 3581024  CS9u9p3IiuKuTYfauc    192.168.1.195     37,306    102.165.48.81
# 3581025   ChLFLFZumxpFdFbV8    192.168.1.195        123   212.111.30.190
# 3581026  CdOxuh15kV4eHJYKkb    192.168.1.195        123       5.1.56.123
# 3581027   C7q9EgOTCtbdacBK3    192.168.1.195        123      81.2.254.32
#
#          id.resp_p proto conn_state  missed_bytes  history  orig_pkts  \
# 0               23   tcp         S0             0        S          3
# 1               23   tcp         S0             0        S          1
# 2               23   tcp         S0             0        S          1
# 3               23   tcp         S0             0        S          3
# 4               23   tcp         S0             0        S          1
# ...            ...   ...        ...           ...      ...        ...
# 3581023        123   udp         SF             0       Dd          2
# 3581024     17,769   tcp         S1             0  ShAdDaT      8,952
# 3581025        123   udp         SF             0       Dd          2
# 3581026        123   udp         SF             0       Dd          2
# 3581027        123   udp         SF             0       Dd          2
#
#          orig_ip_bytes  resp_pkts  resp_ip_bytes            label  anyo  mes  \
# 0                  180          0              0        Malicious  2018    5
# 1                   60          0              0        Malicious  2018    5
# 2                   60          0              0        Malicious  2018    5
# 3                  180          0              0        Malicious  2018    5
# 4                   60          0              0        Malicious  2018    5
# ...                ...        ...            ...              ...   ...  ...
# 3581023            152          2            152           Benign  2019    9
# 3581024        483,602      9,613        520,116  Malicious   C&C  2019    9
# 3581025            152          2            152           Benign  2019    9
# 3581026            152          2            152           Benign  2019    9
# 3581027            152          2            152           Benign  2019    9
#
#          dia  hora  dia_semanal
# 0          9    15            2
# 1          9    15            2
# 2          9    15            2
# 3          9    15            2
# 4          9    15            2
# ...      ...   ...          ...
# 3581023   21     0            5
# 3581024   20     1            4
# 3581025   21     0            5
# 3581026   21     0            5
# 3581027   21     0            5
#
# [25011003 rows x 19 columns]

# %%
#me cargo  la columna ts
df_malware.drop(columns={"ts"}, inplace=True)

# %%
#voya probar triverorizar ña uid a ver q sale
df_malware.to_csv(r"/media/vicevil/Nuevo vol/Cursos/REPOSITORIOS/DATASET/malware_total/original/df_malware_unido_0_pocos_nulos.csv", index=False)

# %%
df_malware=pd.read_csv(r"D:\Cursos\REPOSITORIOS\DATASET\malware_total\original\df_malware_unido_0_pocos_nulos.csv")

# %%
df_malware.head()
# Out:
#                   uid        id.orig_h  id.orig_p        id.resp_h  id.resp_p  \
# 0  CUmrqr4svHuSXJy5z7  192.168.100.103    51524.0   65.127.233.163       23.0
# 1  CH98aB3s1kJeq6SFOc  192.168.100.103    56305.0    63.150.16.171       23.0
# 2   C3GBTkINvXNjVGtN5  192.168.100.103    41101.0     111.40.23.49       23.0
# 3   CDe43c1PtgynajGI6  192.168.100.103    60905.0  131.174.215.147       23.0
# 4  CJaDcG3MZzvf1YVYI4  192.168.100.103    44301.0      91.42.47.63       23.0
#
#   proto conn_state  missed_bytes history  orig_pkts  orig_ip_bytes  resp_pkts  \
# 0   tcp         S0           0.0       S        3.0          180.0        0.0
# 1   tcp         S0           0.0       S        1.0           60.0        0.0
# 2   tcp         S0           0.0       S        1.0           60.0        0.0
# 3   tcp         S0           0.0       S        3.0          180.0        0.0
# 4   tcp         S0           0.0       S        1.0           60.0        0.0
#
#    resp_ip_bytes      label  anyo  mes  dia  hora  dia_semanal
# 0            0.0  Malicious  2018    5    9    15            2
# 1            0.0  Malicious  2018    5    9    15            2
# 2            0.0  Malicious  2018    5    9    15            2
# 3            0.0  Malicious  2018    5    9    15            2
# 4            0.0  Malicious  2018    5    9    15            2

# %%
#me cargo  la columna uid que tambien es un indertificador de alta cardinalidad 
df_malware.drop(columns={"uid"}, inplace=True)

# %%
"""from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

def calcular_idf(df):
    # Obtener todas las columnas que contienen texto
    columnas_texto = df.select_dtypes(include=['object']).columns

    for columna_texto in columnas_texto:
        # Crear un objeto TfidfVectorizer para la columna actual
        vectorizer = TfidfVectorizer(stop_words=df['uid'].tolist())

        # Ajustar el vectorizer a los textos de la columna actual
        matriz_tfidf = vectorizer.fit_transform(df[columna_texto])

        # Obtener los valores IDF de la columna actual
        idf_vector = vectorizer.idf_

        # Convertir el vector IDF a un DataFrame
        df_idf = pd.DataFrame(idf_vector, index=vectorizer.get_feature_names(), columns=[f"Idf_{columna_texto}"])

        # Agregar las nuevas columnas IDF al DataFrame original
        df = pd.concat([df, df_idf.T], axis=1)

    return df"""
# Out:
# 'from sklearn.feature_extraction.text import TfidfVectorizer\nimport pandas as pd\n\ndef calcular_idf(df):\n    # Obtener todas las columnas que contienen texto\n    columnas_texto = df.select_dtypes(include=[\'object\']).columns\n\n    for columna_texto in columnas_texto:\n        # Crear un objeto TfidfVectorizer para la columna actual\n        vectorizer = TfidfVectorizer(stop_words=df[\'uid\'].tolist())\n\n        # Ajustar el vectorizer a los textos de la columna actual\n        matriz_tfidf = vectorizer.fit_transform(df[columna_texto])\n\n        # Obtener los valores IDF de la columna actual\n        idf_vector = vectorizer.idf_\n\n        # Convertir el vector IDF a un DataFrame\n        df_idf = pd.DataFrame(idf_vector, index=vectorizer.get_feature_names(), columns=[f"Idf_{columna_texto}"])\n\n        # Agregar las nuevas columnas IDF al DataFrame original\n        df = pd.concat([df, df_idf.T], axis=1)\n\n    return df'

# %%
df_malware.columns
# Out:
# Index(['id.orig_h', 'id.orig_p', 'id.resp_h', 'id.resp_p', 'proto',
#        'conn_state', 'missed_bytes', 'history', 'orig_pkts', 'orig_ip_bytes',
#        'resp_pkts', 'resp_ip_bytes', 'label', 'anyo', 'mes', 'dia', 'hora',
#        'dia_semanal'],
#       dtype='object')

# %%
bt.obtener_estadisticas(df_malware)
# Out:
#               porcentaje_cardinalidad     Tipo     media            moda  \
# id.orig_h                        0.09   object        No   192.168.1.196
# id.orig_p                        0.26  float64  39909.62              No
# id.resp_h                        46.6   object        No  162.248.88.215
# id.resp_p                        0.26  float64   9710.51              No
# proto                             0.0   object        No             tcp
# conn_state                        0.0   object        No              S0
# missed_bytes                      0.0  float64     76.33              No
# history                           0.0   object        No               S
# orig_pkts                         0.0  float64      13.5              No
# orig_ip_bytes                    0.01  float64    590.02              No
# resp_pkts                         0.0  float64      0.01              No
# resp_ip_bytes                    0.01  float64      1.75              No
# label                             0.0   object        No          Benign
# anyo                              0.0    int64   2018.28              No
# mes                               0.0    int64      8.66              No
# dia                               0.0    int64     21.31              No
# hora                              0.0    int64     12.96              No
# dia_semanal                       0.0    int64      3.81              No
#
#                      std                  var       Q1  mediana       Q3  \
# id.orig_h             No                   No       No       No       No
# id.orig_p       16091.97         258951549.59  32980.0  42993.0  52360.0
# id.resp_h             No                   No       No       No       No
# id.resp_p       22174.48         491707739.75     23.0     23.0     81.0
# proto                 No                   No       No       No       No
# conn_state            No                   No       No       No       No
# missed_bytes   381679.91  145679555881.059998      0.0      0.0      0.0
# history               No                   No       No       No       No
# orig_pkts        17511.7         306659531.76      1.0      1.0      3.0
# orig_ip_bytes  687810.32   473083036333.98999     40.0     60.0    180.0
# resp_pkts           4.19                17.55      0.0      0.0      0.0
# resp_ip_bytes      376.2            141523.04      0.0      0.0      0.0
# label                 No                   No       No       No       No
# anyo                0.45                  0.2   2018.0   2018.0   2019.0
# mes                 3.37                11.36      7.0      9.0     12.0
# dia                 5.98                35.73     21.0     22.0     25.0
# hora                7.85                 61.6      5.0     14.0     21.0
# dia_semanal         1.08                 1.17      3.0      4.0      5.0
#
#                         Categoria porcentaje_NaN
# id.orig_h      categorica ordinal            0.0
# id.orig_p       numerica continua            0.0
# id.resp_h      categorica ordinal            0.0
# id.resp_p       numerica continua            0.0
# proto          categorica ordinal            0.0
# conn_state     categorica ordinal            0.0
# missed_bytes    numerica continua            0.0
# history        categorica ordinal            0.1
# orig_pkts       numerica continua            0.0
# orig_ip_bytes   numerica continua            0.0
# resp_pkts       numerica continua            0.0
# resp_ip_bytes   numerica continua            0.0
# label          categorica ordinal            0.0
# anyo            numerica discreta            0.0
# mes             numerica discreta            0.0
# dia             numerica continua            0.0
# hora            numerica continua            0.0
# dia_semanal     numerica discreta            0.0

# %%
df_malware.shape
# Out:
# (25011003, 18)

# %% [markdown]
# ESETE DATASET ES CON EL PRIMERO Q TRABEJE Y NO ELIMINE NADA - VAMOS A COMPARARLO CON EL DE ARRIBA

# %%
df=pd.read_csv(r"D:\Cursos\REPOSITORIOS\DATASET\malware_total\malware_total.csv")
# Out:
# c:\Users\victo\miniconda3\envs\tf-gpu\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (8,9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
bt.obtener_estadisticas(df)
# Out:
#                         porcentaje_cardinalidad     Tipo       media  \
# Unnamed: 0                                100.0    int64  12505501.0
# Id_session                                100.0   object          No
# Ip_host_org                                0.09   object          No
# Port_org                                   0.26  float64    39909.62
# Ip_host_dest                               46.6   object          No
# Port_dest                                  0.26  float64     9710.51
# Protocol_red                                0.0   object          No
# Service_protocol                            0.0   object          No
# Duration_conexion                          4.32   object          No
# Send_orig_bytes                            0.26   object          No
# receive_orig_bytes                          0.0   object          No
# Status_connect                              0.0   object          No
# Lost_orig_bytes                             0.0   object          No
# Lost_dest_bytes                             0.0   object          No
# missed_bytes                                0.0  float64       76.33
# Info_history_connection                     0.0   object          No
# Send_host_org_packs                         0.0  float64        13.5
# Ip_orig_bytes                              0.01  float64      590.02
# Resquest_receive_packs                      0.0  float64        0.01
# Ip_dest_bytes                              0.01  float64        1.75
# Route_tunnels_used                          0.0   object          No
# Malware_general_label                       0.0   object          No
# Malware_datail_label                        0.0   object          No
# Date                                        0.0   object          No
# Time                                      98.28   object          No
# Time_clock                                  0.0    int64       12.96
# Interval_time                               0.0   object          No
# Anyo                                        0.0    int64     2018.28
# Month                                       0.0    int64        8.66
# Day_week                                    0.0    int64        3.81
#
#                                                moda        std  \
# Unnamed: 0                                       No  7220054.8
# Id_session                       C000004PRnYaVbKEL5         No
# Ip_host_org                           192.168.1.196         No
# Port_org                                         No   16091.97
# Ip_host_dest                         162.248.88.215         No
# Port_dest                                        No   22174.48
# Protocol_red                                    tcp         No
# Service_protocol                                  -         No
# Duration_conexion                                 -         No
# Send_orig_bytes                                   -         No
# receive_orig_bytes                                -         No
# Status_connect                                   S0         No
# Lost_orig_bytes                                   -         No
# Lost_dest_bytes                                   -         No
# missed_bytes                                     No  381679.91
# Info_history_connection                           S         No
# Send_host_org_packs                              No    17511.7
# Ip_orig_bytes                                    No  687810.32
# Resquest_receive_packs                           No       4.19
# Ip_dest_bytes                                    No      376.2
# Route_tunnels_used                                -         No
# Malware_general_label                        Benign         No
# Malware_datail_label                              -         No
# Date                                     2018-12-22         No
# Time                     2024-02-03 22:24:01.997653         No
# Time_clock                                       No       7.85
# Interval_time                                  21-0         No
# Anyo                                             No       0.45
# Month                                            No       3.37
# Day_week                                         No       1.08
#
#                                            var         Q1     mediana  \
# Unnamed: 0               52129191339753.679688  6252750.5  12505501.0
# Id_session                                  No         No          No
# Ip_host_org                                 No         No          No
# Port_org                          258951549.59    32980.0     42993.0
# Ip_host_dest                                No         No          No
# Port_dest                         491707739.75       23.0        23.0
# Protocol_red                                No         No          No
# Service_protocol                            No         No          No
# Duration_conexion                           No         No          No
# Send_orig_bytes                             No         No          No
# receive_orig_bytes                          No         No          No
# Status_connect                              No         No          No
# Lost_orig_bytes                             No         No          No
# Lost_dest_bytes                             No         No          No
# missed_bytes               145679555881.049988        0.0         0.0
# Info_history_connection                     No         No          No
# Send_host_org_packs               306659531.76        1.0         1.0
# Ip_orig_bytes               473083036333.98999       40.0        60.0
# Resquest_receive_packs                   17.55        0.0         0.0
# Ip_dest_bytes                        141523.04        0.0         0.0
# Route_tunnels_used                          No         No          No
# Malware_general_label                       No         No          No
# Malware_datail_label                        No         No          No
# Date                                        No         No          No
# Time                                        No         No          No
# Time_clock                                61.6        5.0        14.0
# Interval_time                               No         No          No
# Anyo                                       0.2     2018.0      2018.0
# Month                                    11.36        7.0         9.0
# Day_week                                  1.17        3.0         4.0
#
#                                  Q3           Categoria porcentaje_NaN
# Unnamed: 0               18758251.5   numerica continua            0.0
# Id_session                       No  categorica ordinal            0.0
# Ip_host_org                      No  categorica ordinal            0.0
# Port_org                    52360.0   numerica continua            0.0
# Ip_host_dest                     No  categorica ordinal            0.0
# Port_dest                      81.0   numerica continua            0.0
# Protocol_red                     No  categorica ordinal            0.0
# Service_protocol                 No  categorica ordinal            0.0
# Duration_conexion                No  categorica ordinal            0.0
# Send_orig_bytes                  No  categorica ordinal            0.0
# receive_orig_bytes               No  categorica ordinal            0.0
# Status_connect                   No  categorica ordinal            0.0
# Lost_orig_bytes                  No  categorica nominal            0.0
# Lost_dest_bytes                  No  categorica nominal            0.0
# missed_bytes                    0.0   numerica continua            0.0
# Info_history_connection          No  categorica ordinal            0.0
# Send_host_org_packs             3.0   numerica continua            0.0
# Ip_orig_bytes                 180.0   numerica continua            0.0
# Resquest_receive_packs          0.0   numerica continua            0.0
# Ip_dest_bytes                   0.0   numerica continua            0.0
# Route_tunnels_used               No  categorica nominal            0.0
# Malware_general_label            No  categorica ordinal            0.0
# Malware_datail_label             No  categorica ordinal          36.68
# Date                             No  categorica ordinal            0.0
# Time                             No  categorica ordinal            0.0
# Time_clock                     21.0   numerica continua            0.0
# Interval_time                    No  categorica ordinal            0.0
# Anyo                         2019.0   numerica discreta            0.0
# Month                          12.0   numerica discreta            0.0
# Day_week                        5.0   numerica discreta            0.0

# %% [markdown]
# VAMOS A SEGUIR TRABAJANDO CON EL DE 18 COLUMNAS, YA QUE EEL FICHERO FINAL ML_MALWAREDL, LO HICE CON EL DE 30 EN OT5RO NOTEBOOK NUEVO
