# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **PROYECTO ML**

# %% [markdown]
# ### Objetivo

# %% [markdown]
# El objetivo del proyecto de Machine Learning es el de evaluar tus capacidades para construir un modelo de ML que resuelva un problema concreto de principio a fin, sin considerar la parte de productización o industrialización. Para ello, se piden desarrollar un conjunto de actividades que den lugar a entregables y luego realizar una exposición oral del trabajo y los resultados. La aproximación puede ser supervisada o no supervisada, y puede utilizar ML tradicional, DL o probar ambos y quedarse con el más adecuado.

# %% [markdown]
# No es objetivo del proyecto resolver un problema específico de la vida real, aunque eso ayuda :-), ni tampoco demostrar que se conoce al dedillo cualquier framework (sklearn, keras) de los vistos, aunque también se tendrá en cuenta como extra. Se valorará más la resolución sensata, el seguimiento razonado de los pasos aprendidos y el análisis claro y bien expuesto de los resultados ligándolos con el problema que se quiere resolver.

# %% [markdown]
# Podéis escoger el dataset y problema que queráis siempre que defendáis con argumentos que este problema tiene algún tipo de solución o ayuda a su solución empleado Machine Learning. Es incluso correcto hacer un EDA siempre que este fuertemente apoyado en Machine Learning.

# %% [markdown]
# ### Entregables

# %% [markdown]
# 1. La dirección de **un repositorio Github público nuevo y dedicado exclusivamente al proyecto** de Machine Learning. En este repositorio debe haber un fichero "Readme.md" en el que se explique el problema que se quiere resolver, se indique el dataset empleado (es decir se describa brevemente, y se indique si es público o privado y en el primer caso se de una forma de acceder a este), se describa brevemente la solución adoptada y se comente la estructura de directorios del repositorio. ***Puntuación (5/100)***, Extra: Hacerlo en inglés y en español (5/100)
#
# 2. **Una muestra del dataset** (no más de 5MB de tamaño) siempre y cuando sea público a incluir en un directorio "data_sample".
#
# 3. **Un notebook claro y conciso con el paso a paso del proceso**. Debe ser un notebook que al ejectutar todo termine por generar el modelo y lo evalúe (como si fuera una práctica obligatoria de clase). Es necesario destacar cada paso empleando headers y negritas, (Por ejemplo **Paso 1: Entendiendo el problema**, **Paso n: Evaluación contra test**, etc). No es tu notebook de trabajo, es el notebook que lo resume, sin alternativas ni probaturas, y que debe fucionar completo. Debe ir en una carpeta "results_notebook" y debe incluirse con él todas las librerías no estándar que se hayan utilizado. IMPORTANTE: Este notebook debe tener como paso final la grabación del modelo en formato "pickle", "joblib" o "h5" (tensorflow) que creáis conveniente. Se valorará tanto el código, como el orden y la claridad. ***Puntuación (55/100)*** Extra: (15/100) realizar el notebook en inglés.
#
# 4. **El documento o soporte que se emplee como apoyo a la exposición oral de resultados** (ver apartado siguiente). Puede ser en el formato que se desee mietras sea reproducible sin necesidad de software comercial. ***Puntuación (5/100)***. Extra: Entregar una versión en inglés (10/100)

# %% [markdown]
# ### Exposición del proyecto

# %% [markdown]
# A diferencia del proyecto del EDA en el que la presentación es casi tan importante o más que el desarrollo del análisis, en este caso lo realmente importante es llegar al mejor modelo posible de forma razonada. Pero no por ello, exponer los resultados es algo a descuidar.
#
# Se pide:
# - Realizar **una exposición oral, con los medios que se consideren necesarios,** del problema, proceso, resultados y análisis de los mismos. **El máximo de tiempo sin preguntas es de 25 minutos** a partir de ahí el exceso de tiempo consumido contará negativamente. La exposición se hará en castellano.  ***Puntuacion (35/100)***

# %% [markdown]
# Guía:
#
# A continuación se da una guía para la exposición que debe considerarse como lo que es una guía, no es obligatorio ceñirse a ella mientras se cubran los aspectos requeridos.
#
# 1. Presentación del problema de negocio. Por ejemplo: Ayudar a reducir la mortalidad por cáncer de mama. Reducir los gastos de mantenimiento de las centrales nucleares. [3 min]
#
# 2. Planteamiento del problema técnico y cómo resuelve o ayudar a resolver el problema de negocio: Predicción de aparición de cáncer en los próximos dos años, ayuda porque pueden aplicarse técnicas preventivas. Predicción del mejor momento para hacer una revisión completa, ayuda en la planificación de las revisiones (vaciados de los generadores principales) y a hacerlas coordinadas para que no suba el gasto eléctrico. [5 min]
#
# 3. Descripción del dataset y miniEDA (target si lo hubiera, agrupaciones más interesantes en un clustering, features más predictivas, etc) [5 min]
#
# 4. Arquitectura de la solución, modelos probados, resultados de la comparativa (si la hubiera). Modelo seleccionado final (o modelos si fuera un combinado) y resultado contra test o resultado de las agrupaciones [10 min]
#
# 5. Conclusiones finales y acciones de mejora [2 min]

# %% [markdown]
# ### Plazos
#
# **Las presentaciones se realizarán del 4 al 8 de abril en horarios de clase**. Se habilitará un mecanismo (probablemente las citas de Google) para que puedas escoger el turno disponible que mejor te convenga. Para poder realizar la exposición **es obligatorio haber enviado la dirección del repositorio (ver apartado de Entregables) a los TAs y haberlo completado con el resto de entregables como mínimo 1 hora antes de la cita**. Se podrá escoger turno hasta 48 horas antes del mismo.

# %% [markdown]
# ### Tutorias

# %% [markdown]
# Durante la semana del 18 de marzo y 4 de abril se habilitarán turnos de tutorías específicas para el proyecto con el LI y un TA. Las tutorias normales siguen operativas. Durante la semana del 25 de abril se podrán solicitar tutorías especiales que dependerán de la disponibilidad del LI.

# %% [markdown]
# ### Sugerencias

# %% [markdown]
# Si todavía no tienes elegido tema, te dejamos aquí una serie de "problemas" que pueden ser interesantes, algunos ya se han abordado en ediciones anteriores (ojo son problemas "técnicos", tendrás que recubrirlos de un problema de negocio):
#
# 1. Predecir el final de la subida de bitcoin debido al "halving".
#
# 2. Predecir quien ganará una partida de LoL sabiendo el desarrollo a mitad de la misma.
#
# 3. Etiquetado no supervisado de la calidad de pisos en función de sus fotografías.
#
# 4. Estimación de si un precio está por encima o por debajo de mercado (aplicable a muchos ámbitos: inmobiliario, consumibles, etc)
#
# 5. Etiquetado de titulares (A qué periodico o medio informativo pertenece un titular determinado) para recomendador de lecturas personales.
#
# 6. Predictor del resultado electoral en función de las encuestas.
#
# 7. Quién ganará un partido de futbol en función de los goles marcados por cada equipo.
#
# 8. Predictor de la recaudación de taquilla de una película en función de sus actores, género, fecha de estreno y sipnosis.
#
# 9. Clasificador del sesgo político de un medio de comunicación en función de sus titulares.
