# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # TABLA DEL DATASET CYBERATTACKS

# %% [markdown]
#  Nombre del campo                  | Descripción                                                                 | Tipo de variable | Importancia Inicial | Notas |
# |-----------------------------------|----------------------------------------------------------------------------|------------------|---------------------|---------------------|
# | Fecha_hora                        | fecha y hora de los ataques                                                |categorica ordinal| importante          |                     |
# | IP Origen                         | Ip origen de los ataques                                                   |numerica dis.     | target              |                     |
# | Destino IP                        | Ip destino de los ataques                                                  |numerica discreta |  target             |                     |
# | Puerto_origen                     | Puerto a traves del cual parten la Ip de los ataques                       |numérica discreta |                     | NaN                 |
# | Puerto_destino                    | Puerto a traves del cual llegan las Ip de los ataques                      |numérica discreta |                     | NaN                 |
# | Protocolo                         | capas de transportes IP: ICMP/UDP/TCP.                                     |categorica ordinal|                     |                     |
# | Longitud_paquete                  | tamaño del paquete de datos que se está transmitiendo a través de una red  |numerica discreta |                     |se expresa en Bytes  |
# | Tipo_paquete                      | clasificación del paquete de datos que se está transmitiendo por la red    |binaria           |                     |                     |
# | Tipo                              |prot. usados en redes de computadoras para realizar funciones específicas   |categórica ordinal|                     |http dns Ftp         |
# | Datos_carga_util                  | datos de un paquete de red necesarios para la transmisión efectiva         |categórica ordinal|                     |                     |
# | Indicadores_malware               | patrones  identificar la presencia o actividad maliciosa en la red         |categórica ordinal|                     |                     |
# | Puntuaciones_anomalías            | patrones que se generan mediante IAs que sobrepasan el umbral permimitido  |numérica discreta |                     |                     |
# | Alertas_advertencias              | notificaciones diseñadas para informar sobre situaciones críticas          |categórica ordinal|                     |NaN-Alert Triggered  |
# | Tipo_ataque                       | ataque informático basada en la naturaleza, el método y los objetivos      |categórica ordinal|                     |                     |
# | Firma_ataque                      | patróne de características identificables asociados a un tipo ataque       |binaria           |                     |                     |
# | respuesta_tomada                  | acciones de seguridad en respuesta a un evento o a un ataque detectado     |categórica ordinal|                     |                     |
# | Nivel_severidad                   | indican la gravedad o importancia de una alerta o evento                   |categórica ordinal|                     |                     |
# | Informacion_usuario               | datos y detalles relacionados con un usuario en un sistema o plataforma    |categórica ordinal|                     |                     |
# | Informacion_dispositivo           | identificar el navegador y el S.O desde el cual se realiza una solicitud   |categórica ordinal| importante          | datos navegador     |
# | Segmento_red                      | objetivo de mejorar la eficiencia, la seguridad y la administración - red  |categórica ordinal|                     |                     |
# | Datos_geolocalización             | Ubicacion de las direcciones IP origen y destino de los ataques            |categórica ordinal|  Target             |                     |
# | Información_proxy                 | intermediario entre los usuarios y los servidores                          |numérica continua |                     |        NaN          |
# | Registros_cortafuegos             | registros detallados de las actividades y eventos de una firewall          |categorica ordinal|                     |                     |
# | Alertas IDS / IPS                 |notificaciones de sistemas en respuesta a patrones de act. maliciosas       |categórica ordinal|S.Detec.de Intrusiones y Preven. de ellas  |
# | Fuente_registro                   |fuente o origen de la información registrada en un registro o log           | binaria          |                     |                     |

# %%
import sys
sys.path.append("E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\funciones_analisis.py")
import pandas as pd

#from importlib import reload
#reload(funciones_analisis)
from funciones_analisis import *

# %%
import pandas as pd
import numpy as np
# Configurar pandas para mostrar todas las filas y columnas
#pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#pd.set_option('display.width', None)
#pd.set_option('display.max_colwidth', None)


df_ciber_modificado=pd.read_excel(r"E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\DATASETS MODIFICADOS\ciber_modificado.xlsx")

# %%
df_ciber_modificado.head(2)
# Out:
#    Unnamed: 0          Fecha_hora       IP Origen      Destino IP  \
# 0           0 2023-05-30 06:33:58   103.216.15.12    84.9.164.252
# 1           1 2020-08-26 07:08:30  78.199.217.198  66.191.137.154
#
#    Puerto_origen  Puerto_destino Protocolo  Longitud_paquete Tipo_paquete  \
# 0          31225           17616      ICMP               503         Data
# 1          17245           48166      ICMP              1174         Data
#
#    Tipo                                   Datos_carga_util  \
# 0  HTTP  El que nació del odio por el que se puso.La op...
# 1  HTTP  Ábrelos a los modos de los deberes de la verda...
#
#   Indicadores_malware  Puntuaciones_anomalias Tipo_ataque     Firma_ataque  \
# 0        IoC Detected                    2867     Malware  Known Pattern B
# 1        IoC Detected                     515     Malware  Known Pattern A
#
#   respuesta_tomada Nivel_severidad Informacion_usuario  \
# 0           Logged             Low       Reyansh Dugal
# ...

# %%
df_ciber_modificado2.to_excel(r"E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\DATASETS MODIFICADOS\ciber_modificado.xlsx")

# %%
df_ciber_modificado2.drop(columns="Alertas IDS (SisterC_intrusos/IPS (Sister_Preve_intrusos)", inplace=True)

# %%
df_ciber_modificado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               40000 non-null  int64
#  1   Fecha_hora               40000 non-null  datetime64[ns]
#  2   IP Origen                40000 non-null  object
#  3   Destino IP               40000 non-null  object
#  4   Puerto_origen            40000 non-null  int64
#  5   Puerto_destino           40000 non-null  int64
#  6   Protocolo                40000 non-null  object
#  7   Longitud_paquete         40000 non-null  int64
#  8   Tipo_paquete             40000 non-null  object
#  9   Tipo                     40000 non-null  object
#  10  Datos_carga_util         40000 non-null  object
#  11  Indicadores_malware      20000 non-null  object
#  12  Puntuaciones_anomalias   40000 non-null  int64
#  13  Tipo_ataque              40000 non-null  object
# ...

# %%
df_ciber_modificado= df_ciber_modificado.rename(columns={"Puntuaciones_anomalías":"Puntuaciones_anomalias", "Datos_geolocalización":"Datos_geolocalizacion"})

# %%
df_ciber_modificado.to_excel(r"E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\DATASETS MODIFICADOS\ciber_modificado.xlsx")

# %%
# en cibermodificado se han quitado los puntos de las IPs, asi que voy a restaurar las columnas del original.


# Cargar los datasets
original=pd.read_csv(r"E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\cybersecurity_attacks.csv")
copia =pd.read_excel(r"E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\DATASETS MODIFICADOS\ciber_modificado.xlsx")

# Seleccionar las columnas a copiar
columnas_a_copiar = ["Source IP Address", "Destination IP Address", "Proxy Information"]

# Copiar las columnas al dataset de copia
copia["IP Origen"] = original["Source IP Address"]
copia["Destino IP"] = original["Destination IP Address"]
copia["Información_proxy"] = original["Proxy Information"]

# Guardar el dataset de copia
copia.to_excel(r"E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\DATASETS MODIFICADOS\ciber_modificado2.xlsx")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 6
#       1 # en cibermodificado se han quitado los puntos de las IPs, asi que voy a restaurar las columnas del original.
#       2
#       3
#       4 # Cargar los datasets
#       5 original=pd.read_csv(r"E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\cybersecurity_attacks.csv")
# ----> 6 copia =pd.read_excel(r"E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\DATASETS MODIFICADOS\ciber_modificado.xlsx")
#       8 # Seleccionar las columnas a copiar
#       9 columnas_a_copiar = ["Source IP Address", "Destination IP Address", "Proxy Information"]
#
# ...

# %%
df_ciber_modificado2=pd.read_excel(r"E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\DATASETS MODIFICADOS\ciber_modificado2.xlsx")

# %%
df_ciber_modificado["IP Origen"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40000 entries, 0 to 39999
# Series name: IP Origen
# Non-Null Count  Dtype
# --------------  -----
# 40000 non-null  int64
# dtypes: int64(1)
# memory usage: 312.6 KB

# %%
# Verificar si hay valores nulos 
columna_de_interes = 'IP Origen'
tiene_NaN = df_ciber_modificado[columna_de_interes].isnull().any()

if tiene_NaN:
    print(f'La columna "{columna_de_interes}" tiene valores NaN')
else:
    print(f'La columna "{columna_de_interes}" no tiene valores NaN')
# Out:
# La columna "IP Origen" no tiene valores NaN

# %%
df_ciber_modificado["Destino IP"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40000 entries, 0 to 39999
# Series name: Destino IP
# Non-Null Count  Dtype
# --------------  -----
# 40000 non-null  int64
# dtypes: int64(1)
# memory usage: 312.6 KB

# %%
# Verificar si hay valores nulos 
columna_de_interes = 'Destino IP'
tiene_NaN = df_ciber_modificado[columna_de_interes].isnull().any()

if tiene_NaN:
    print(f'La columna "{columna_de_interes}" tiene valores NaN')
else:
    print(f'La columna "{columna_de_interes}" no tiene valores NaN')
# Out:
# La columna "Destino IP" no tiene valores NaN

# %%
df_ciber_modificado.Tipo_ataque.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40000 entries, 0 to 39999
# Series name: Tipo_ataque
# Non-Null Count  Dtype
# --------------  -----
# 40000 non-null  object
# dtypes: object(1)
# memory usage: 312.6+ KB

# %%
# Verificar si hay valores nulos 
columna_de_interes = 'Tipo_ataque'
tiene_NaN = df_ciber_modificado[columna_de_interes].isnull().any()

if tiene_NaN:
    print(f'La columna "{columna_de_interes}" tiene valores NaN')
else:
    print(f'La columna "{columna_de_interes}" no tiene valores NaN')
# Out:
# La columna "Tipo_ataque" no tiene valores NaN

# %%
df_ciber_modificado.Datos_geolocalización.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40000 entries, 0 to 39999
# Series name: Datos_geolocalización
# Non-Null Count  Dtype
# --------------  -----
# 40000 non-null  object
# dtypes: object(1)
# memory usage: 312.6+ KB

# %%
# Verificar si hay valores nulos 
columna_de_interes = 'Datos_geolocalización'
tiene_NaN = df_ciber_modificado[columna_de_interes].isnull().any()

if tiene_NaN:
    print(f'La columna "{columna_de_interes}" tiene valores NaN')
else:
    print(f'La columna "{columna_de_interes}" no tiene valores NaN')
# Out:
# La columna "Datos_geolocalización" no tiene valores NaN

# %% [markdown]
# Relacion entre Tipo, Indicadores_malware y Tipo_ataque(categoricas ordinales)

# %%
df_ciber_modificado.Alertas_advertencias.unique()
# Out:
# array([nan, 'Alert Triggered'], dtype=object)

# %%
columnas_categoricas =["Tipo", "Indicadores_malware","Tipo_ataque"]

# %%
# cardinalidad y tipo de columnas

columnas_cardin(df_ciber_modificado)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # cardinalidad y tipo de columnas
# ----> 3 columnas_cardin(df_ciber_modificado)
#
# NameError: name 'columnas_cardin' is not defined

# %%
pinta_distribucion_categoricas(df_ciber_modificado, columnas_categoricas, relativa=False, mostrar_valores=False)

# %%
plot_categorical_relationship_fin(df_ciber_modificado,"Tipo", "Tipo_ataque" , relative_freq=True, show_values=False, size_group = 5)

# %%
# TIPO
df_ciber_modificado.Tipo.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 40000 entries, 0 to 39999
# Series name: Tipo
# Non-Null Count  Dtype
# --------------  -----
# 40000 non-null  object
# dtypes: object(1)
# memory usage: 312.6+ KB

# %%
df_ciber_modificado.Tipo.unique()
# Out:
# array(['HTTP', 'DNS', 'FTP'], dtype=object)

# %%
df_ciber_modificado.Tipo.value_counts()
# Out:
# Tipo
# DNS     13376
# HTTP    13360
# FTP     13264
# Name: count, dtype: int64
