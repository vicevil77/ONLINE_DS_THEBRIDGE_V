# %%
import geopandas as gpd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import sketch
from shapely.geometry import Point
import time
from translate import Translator

# Configurar pandas para mostrar todas las filas y columnas
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

df = pd.read_excel("E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\DATASETS MODIFICADOS\ciber_modificado.xlsx")

# %% [markdown]
# # unir los excel de karspexky que solo tienen un campo country y otro de datos numeritcos, con la intecion qde al final quedarme una lista de counyry y 3 datos numericos

# %%
dfk_ransom = pd.read_excel("E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\KARPESKY\securelist_ransomware_day_2023-11-30.xlsx")

# %%
dfk_exploit = pd.read_excel("E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\KARPESKY\EXPLOITS_securelist_vulnerability-scan_day_2023-11-30.xlsx")

# %%
dfk_amenaza_web = pd.read_excel("E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\KARPESKY\AMENAZAS WEB_securelist_web-anti-virus_day_2023-11-30.xlsx")

# %%
dfk_ataques_red = pd.read_excel("E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\KARPESKY\ATAQUES_RED_securelist_intrusion-detection-scan_day_2023-11-30.xlsx")

# %%
dfk_bajo_demanda = pd.read_excel("E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\KARPESKY\BAJO_DEMANDAsecurelist_on-demand-scan_day_2023-11-30.xlsx")

# %%
df_concat = dfk_ransom + dfk_exploit + dfk_amenaza_web + dfk_ataques_red + dfk_bajo_demanda

# %%
df_concat
# Out:
#                                                                                                                                                                        country  \
# 0                                               República Islámica de AfganistánRepública de Guinea EcuatorialRepública de MoldovaRepública de CoreaRepública de Guinea-Bissau
# 1                                                                  TurkmenistánRepública de la Unión de MyanmarRepública de LetoniaRepública Socialista de VietnamTurkmenistán
# 2                                               Reino de LesothoEstados Unidos de AméricaRepública de MalawiRepública Popular de ChinaRepública Argelina Democrática y Popular
# 3                                                               República Islámica de PakistánGuayanaRepública de MadagascarRepública de GhanaRepública Islámica de Afganistán
# ...

# %%
df_concat["country"].unique()
# Out:
# array(['República Islámica de AfganistánRepública de Guinea EcuatorialRepública de MoldovaRepública de CoreaRepública de Guinea-Bissau',
#        'TurkmenistánRepública de la Unión de MyanmarRepública de LetoniaRepública Socialista de VietnamTurkmenistán',
#        'Reino de LesothoEstados Unidos de AméricaRepública de MalawiRepública Popular de ChinaRepública Argelina Democrática y Popular',
#        'República Islámica de PakistánGuayanaRepública de MadagascarRepública de GhanaRepública Islámica de Afganistán',
#        'República Islámica de IránCanadáNación de Brunei, Morada de la PazRepública Islámica de IránRepública de la Unión de Myanmar',
#        'República de YemenRepública de NígerRepública de Guinea EcuatorialRepública Democrática Popular LaoRepública del Congo',
#        'República de CoreaPrincipado de AndorraReino de LesothoRepública de IndonesiaMongolia',
#        'BeliceRepública Federal de AlemaniaRepública de AngolaRepública Árabe de EgiptoRepública de Togo',
# ...

# %%
df_concat.drop([145, 192])
# Out:
#                                                                                                                                                                        country  \
# 0                                               República Islámica de AfganistánRepública de Guinea EcuatorialRepública de MoldovaRepública de CoreaRepública de Guinea-Bissau
# 1                                                                  TurkmenistánRepública de la Unión de MyanmarRepública de LetoniaRepública Socialista de VietnamTurkmenistán
# 2                                               Reino de LesothoEstados Unidos de AméricaRepública de MalawiRepública Popular de ChinaRepública Argelina Democrática y Popular
# 3                                                               República Islámica de PakistánGuayanaRepública de MadagascarRepública de GhanaRepública Islámica de Afganistán
# ...
