# %%
import numpy as np  
import pandas as pd 



df=pd.read_excel("E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\DATASETS MODIFICADOS\Ransom_reducido.xlsx")

# %%
df
# Out:
#      Codigo_anyo  Anyo  Mes           Objetivo      Sector     Paises
# 0              1  2021  JUL             Kaseya        tech        USA
# 1              1  2021  JUN     Salvation Army         NaN         UK
# 2              1  2021  JUN       Grupo Fleury  healthcare     Brazil
# 3              1  2021  JUN      City of Liege  government    Belgium
# 4              1  2021  JUN  Lucky Star Casino         NaN        USA
# ..           ...   ...  ...                ...         ...        ...
# 353            6  2015  NaN       "TeslaCrypt"       mixed  Worldwide
# 354            6  2014  JUN   New Hampshire PD  government        USA
# 355            6  2014  MAY      Apple devices       mixed  Australia
# 356            6  2014  NaN       "Cryptowall"       mixed  Worldwide
# 357            6  2013  NaN     "Cryptolocker"       mixed  Worldwide
#
# [358 rows x 6 columns]

# %%
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
#cambia nombre todas las columnas
#df_reducido=df_reducido.set_axis(["Codigo_anyo", "Anyo","Mes","Objetivo","Sector","Paises"], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358 entries, 0 to 357
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   358 non-null    int64
#  1   Codigo_anyo  358 non-null    int64
#  2   Anyo         358 non-null    int64
#  3   Mes          353 non-null    object
#  4   Objetivo     358 non-null    object
#  5   Sector       351 non-null    object
#  6   Paises       358 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 19.7+ KB

# %%
columna=pd.read_excel("E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\DATASETS MODIFICADOS\columna_grupos.xlsx")

# %%
columna
# Out:
#      Cibercriminales_ ransomware
# 0                         Kaseya
# 1                 Salvation Army
# 2                   Grupo Fleury
# 3                  City of Liege
# 4              Lucky Star Casino
# ..                           ...
# 167          Electrobras & Copel
# 168                   Kia Motors
# 169                   CD Projekt
# 170                          MNH
# 171     Dutch Research Council).
#
# [172 rows x 1 columns]

# %%
# Asignar la nueva columna al DataFrame más grande sin modificar su estructura
df_ransom=df.assign(Cibergrupos_ransom=columna[' Cibercriminales_ ransomware'])

# %%
df_ransom
# Out:
#      Codigo_anyo  Anyo  Mes           Objetivo      Sector     Paises  \
# 0              1  2021  JUL             Kaseya        tech        USA
# 1              1  2021  JUN     Salvation Army         NaN         UK
# 2              1  2021  JUN       Grupo Fleury  healthcare     Brazil
# 3              1  2021  JUN      City of Liege  government    Belgium
# 4              1  2021  JUN  Lucky Star Casino         NaN        USA
# ..           ...   ...  ...                ...         ...        ...
# 353            6  2015  NaN       "TeslaCrypt"       mixed  Worldwide
# 354            6  2014  JUN   New Hampshire PD  government        USA
# 355            6  2014  MAY      Apple devices       mixed  Australia
# 356            6  2014  NaN       "Cryptowall"       mixed  Worldwide
# 357            6  2013  NaN     "Cryptolocker"       mixed  Worldwide
#
#     Cibergrupos_ransom
# 0               Kaseya
# 1       Salvation Army
# 2         Grupo Fleury
# 3        City of Liege
# ...

# %%
 # Convertir la columna a lista
nombres_repetidos = df_ransom["Cibergrupos_ransom"].tolist() 
 # Comprobar si los valores en 'Objetivo' están en 'nombres_repetidos'
filas_eliminar = df_ransom['Objetivo'].isin(nombres_repetidos) 
# Mantener solo las filas donde 'filas_eliminar' es Falso
df_ransom = df_ransom[~filas_eliminar]

# %%
df_ransom.to_excel("E:\Cursos\BC_Data_Science\Repositorio\ONLINE_DS_THEBRIDGE_V\proyecto EDA\DATASETS\DATASETS MODIFICADOS\df_random_final.xlsx", index=False)

# %%
df_ransom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 194 entries, 13 to 357
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Codigo_anyo         194 non-null    int64
#  1   Anyo                194 non-null    int64
#  2   Mes                 189 non-null    object
#  3   Objetivo            194 non-null    object
#  4   Sector              193 non-null    object
#  5   Paises              194 non-null    object
#  6   Cibergrupos_ransom  8 non-null      object
# dtypes: int64(2), object(5)
# memory usage: 12.1+ KB

# %%
df_ransom = df_ransom.reset_index(drop=True)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 358 entries, 0 to 357
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Codigo_anyo         358 non-null    int64
#  1   Anyo                358 non-null    int64
#  2   Mes                 353 non-null    object
#  3   Objetivo            358 non-null    object
#  4   Sector              351 non-null    object
#  5   Paises              358 non-null    object
#  6   Cibergrupos_ransom  172 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 22.4+ KB

# %%
len(df.Objetivo.unique())# todos son valore unicos, de ellos 135 son nombre de grupos cibercriminales especializados en Ransomware
df.Objetivo.unique()
# Out:
# array(['Kaseya', 'Salvation Army', 'Grupo Fleury', 'City of Liege',
#        'Lucky Star Casino', 'MRWD', 'RBA', 'Judson ISD',
#        'Humber River Hospital', 'DMACC', 'Town of Freeport', 'Invenergy',
#        'Sol Oriens', 'Edward Don', "Skinners' schools", 'ADATA',
#        'LineStar', 'iConstituent', 'St. Clair County', 'UF Health',
#        'Steamship Authority', 'ParkMobile', 'Sierra College',
#        'Betenbough', 'Waikato Hospitals', 'AXA ', 'Ireland HSE',
#        'Yamabiko', 'City of Tulsa', 'Volue Technology', 'Scripps Health',
#        'Swiss Cloud', 'Presque Isle PD', 'Whistler', 'Aspire',
#        'Merseyrail', 'UnitingCare', 'VTA', 'MPD', 'Gyrodata', 'Hoya ',
#        'The Dixie Group', 'NBU', 'University of Portsmouth',
#        'Owner Federal Group', 'Bakker Logistiek', 'Durham',
#        'City of Lawrence', 'JBI', 'Haverhill School', 'NCI',
#        'Technological University', 'Home Hardware Stores', 'Applus',
# ...

# %%
len(df.Objetivo.value_counts())
# Out:
# 358

# %%
df.Sector.value_counts()# sectores mas atacados gobiernos, empresa "tech""salud", "academicas"
# Out:
# Sector
# government             59
# tech                   57
# healthcare             50
# academic               39
# logistics              22
# finance                18
# energy                 15
# transport              15
# retail                 13
# media & sports          9
# food & beverage         9
# mixed                   8
# legal                   7
# misc                    7
# automotive              5
# gaming                  4
# telecomms               4
# telecoms                3
# military                2
# healthcare, tech        1
# tech                    1
# finace                  1
# logistics, telecoms     1
# media                   1
# Name: count, dtype: int64
