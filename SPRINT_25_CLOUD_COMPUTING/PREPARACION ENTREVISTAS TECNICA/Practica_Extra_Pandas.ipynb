# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PRACTICA EXTRA - PANDAS
#
# Completa la práctica y entregala en tu repositorio personal en una carpeta con el nombre "RECUPERACION_SPRINT_4".
#
#
# NOTA: Ejercicio sacado directamente de una entrevista de trabajo para una conocida compañía de retail.

# %% [markdown]
# ## Modelo de Datos
#
# La siguiente figura muestra un modelo de datos de una base de datos relacional. Se pide completar los ejercicios empleando únicamente pandas.

# %% [markdown]
# ![Tablas-1.png](attachment:Tablas-1.png)
# ![Tablas-3.png](attachment:Tablas-3.png)

# %%
import pandas as pd

# %% [markdown]
# ### 1.
# Crea un DataFrame por cada tabla

# %%
df_familia=pd.DataFrame({'ID_DPTO':[1,1,2,3,3,4], 'COD_FAMILIA':['1F1','1F2','2F1','3F1','3F2','4F1'],'DESC_FAMILIA':['PULSERAS','ANILLOS','BOLSO DE MANO','NAUTICO', 'SANDALIAS','BERMUDAS']})

# %%
df_familia.head()
# Out:
#    ID_DPTO COD_FAMILIA   DESC_FAMILIA
# 0        1         1F1       PULSERAS
# 1        1         1F2        ANILLOS
# 2        2         2F1  BOLSO DE MANO
# 3        3         3F1        NAUTICO
# 4        3         3F2      SANDALIAS

# %%
df_departamento=pd.DataFrame({'ID_DPTO':[1,2,3,4],'DESC_DPTO':['JOYERIA','BOLSOS','ZAPATERIA','BAÑO CAB.']})

# %%
df_departamento.head()
# Out:
#    ID_DPTO  DESC_DPTO
# 0        1    JOYERIA
# 1        2     BOLSOS
# 2        3  ZAPATERIA
# 3        4  BAÑO CAB.

# %%
df_articulo=pd.DataFrame({'REFERENCIA':['A', 'B','C','D','E','F','G','H'], 'ID_DPTO':[1,2,2,2,2,3,3,4], 'COD_FAMILIA':['1F1A','1F1B','1F2A','1F2B','2F1A','3F1A','3F2A','4F1A'],'FECHA_ALTA':['21/02/2010','07/02/2014','15/05/2014','01/10/2005','31/10/2010','20/04/2001','14/02/2015','25/03/2009']})

# %%
df_articulo.head()
# Out:
#   REFERENCIA  ID_DPTO COD_FAMILIA  FECHA_ALTA
# 0          A        1        1F1A  21/02/2010
# 1          B        2        1F1B  07/02/2014
# 2          C        2        1F2A  15/05/2014
# 3          D        2        1F2B  01/10/2005
# 4          E        2        2F1A  31/10/2010

# %%
df_companias=pd.DataFrame({'ID_COMPANIA': ['CA1', 'CA2', 'CA3', 'CA4', 'CA5', 'CA6'], 'TIPO': ['VENTA', 'VENTA', 'POSVENTA', 'VENTA', 'POSVENTA','POSVENTA'], 'FECHA_CAMP': ['05/02/2012','04/02/2012','02/10/2009','06/05/2010','31/11/2010','07/02/2015']})

# %%
df_companias.head()
# Out:
#   ID_COMPANIA      TIPO  FECHA_CAMP
# 0         CA1     VENTA  05/02/2012
# 1         CA2     VENTA  04/02/2012
# 2         CA3  POSVENTA  02/10/2009
# 3         CA4     VENTA  06/05/2010
# 4         CA5  POSVENTA  31/11/2010

# %%
df_depto_compania=pd.DataFrame({'ID_DPTO':[1,1,2,3,3,3,4,4,4,4], 'ID_COMPANIA': ['CA1', 'CA4', 'CA2', 'CA2', 'CA5', 'CA6', 'CA1', 'CA2', 'CA3', 'CA6']})

# %%
df_depto_compania.head()
# Out:
#    ID_DPTO ID_COMPANIA
# 0        1         CA1
# 1        1         CA4
# 2        2         CA2
# 3        3         CA2
# 4        3         CA5

# %%
df_venta=pd.DataFrame({"TALON":["01","02","03","04","05","06","07","08"], "REFERENCIA":["A","A","A","D","E","E","H","H"], "PRECIO":[15,18,14,37.95,125.95,150,22.99,24], "FECHA_VENTA":["11/02/2012","15/02/2012","02/10/2013","06/08/2010","31/11/2010","05/02/2011","11/04/2010","08/08/2011"]})

# %%
df_venta.head()
# Out:
#   TALON REFERENCIA  PRECIO FECHA_VENTA
# 0    01          A   15.00  11/02/2012
# 1    02          A   18.00  15/02/2012
# 2    03          A   14.00  02/10/2013
# 3    04          D   37.95  06/08/2010
# 4    05          E  125.95  31/11/2010

# %% [markdown]
# ### 2.
# Genera una consulta que obtenga la lista ordenada de todas las referencias sin venta

# %%
#Genera una consulta que obtenga la lista ordenada de todas las referencias sin venta

df_referencias_sin_venta=pd.merge(df_articulo, df_venta, df_familia, df_departamento, df_companias,df_depto_compania, on='REFERENCIA', how='right')

df_referencias_sin_venta
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 #Genera una consulta que obtenga la lista ordenada de todas las referencias sin venta
# ----> 3 df_referencias_sin_venta=pd.merge(df_articulo, df_venta, df_familia, df_departamento, df_companias,df_depto_compania, on='REFERENCIA', how='right')
#       5 df_referencias_sin_venta
#
# TypeError: merge() got multiple values for argument 'on'

# %% [markdown]
# ### 3.
# Genera una consulta que obtenga las ventas comprendidas entre 2010 y 2011 (ambos incluidos), que estén asociados a una campaña de tipo VENTA y que sean del departamento de JOYERÍA.

# %% [markdown]
# ### 4.
# Genera una consulta que cree un campo “co_ranking” que clasifique en orden ascendente las campañas según el total de venta, siendo 1 la campaña que más ha vendido y N la que menos. (N = Total de campañas)

# %% [markdown]
# ### 5.
# Clasifica todas las ventas en Mayor, Igual o Menor precio respecto a la media de los precios de todas las ventas realizadas.

# %% [markdown]
# **Resultado**:
#
# ![Tablas-4.png](attachment:Tablas-4.png)

# %% [markdown]
# ### 6.
# Genera una consulta que para cada campaña de tipo “venta” obtenga el talón medio, precio medio, nº de referencias compradas y nº de talones con venta superior al talón medio.

# %% [markdown]
# ### 7.
# Genera una o varias consultas que devulevan las combinaciones de familias y campañas cuya venta haya sido superior a 100€.

# %% [markdown]
# ### 8.
# Genere una o varias consultas que permitan catalogar los artículos vendidos y que no son de la Campaña CA1, según si se tratan de artículos de Ropa o Accesorios. En base a los departamentos y familias. NOTA: Se valorará la elaboración de la consulta y no la veracidad del propio catálogo)

# %% [markdown]
# ### 9.
# Genera una o varias consultas que devuelvan la variación del total de venta entre años. Tomando como variación la siguiente fórmula $$\dfrac{Year_{n} – Year_{n-1}}{Year_{n-1}}$$ (Se valorará el control de valores 0 en la división o de indeterminaciones)

# %% [markdown]
# ![Tablas-5.png](attachment:Tablas-5.png)
