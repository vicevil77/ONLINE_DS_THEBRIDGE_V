# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # RAMP-UP ONLINE. MODELO T1

# %% [markdown]
# ## INSTRUCCIONES

# %% [markdown]
# 1. Tienes dos horas para realizar el ejercicio (sobre este mismo notebook que debes haber copiado previamente en otro directorio que no sea tu versión local del de ejercicios del bootcamp)
# 2. En esas dos horas además se pide realizar un pequeño vídeo explicando la ejecución (correcta o incorrecta) del ejercicio de la parte III (apartados 4 a 8). Recuerda reservarte tiempo para poder grabarlo.
# 3. Si no se ha realizado el ejercicio de la parte III, el vídeo debe explicar el o los ejercicios realizados de la parte II.
# 4. El notebook debes subirlo a tu repositorio personal antes de finalizado el plazo. El retraso conlleva una penalización en la nota.
# 5. El video se enviará por correo electrónico o por md/dm en slack a cualquiera de los dos TAs.
# 6. Puedes utilizar internet, AI, lo que quieras, bajo tu propia responsabilidad.
# 7. Se puntuarán extra los comentarios en el código de las partes II y III.
# 8. El aprobado son 5 puntos, y se pueden sacar más de 10.
# 9. Ejecuta las dos celdas que vienen a continuación. Lee la salida con atención.

# %%
nombre = ""
apellidos = ""

# %%
print(f"Hola, {nombre} {apellidos}, mucho ánimo. Solo hay victorias o aprendizajes.")
print("Y recuerda que nos dirá más de tu capacidad de desarrollar código cualquier cosa que escribas que una celda vacía.")
print(f"Ah, {nombre} y no hay límites al número de celdas que quieras usar.")

# %% [markdown]
# ## PARTE I. VARIABLES Y  COLECCIONES [3.5 puntos]

# %% [markdown]
# ### Ejercicio 1.1 (1 punto)
#
# Vamos a completar tu ficha de cliente. Para ello:
#
# 1. Crea una variable `edad` de tipo int y asignale tu edad (o la que quieras tener)
# 2. Crea una variable `altura` de tipo float y asignale tu altura en el formato (metros.centimetros es decir 1 metro 80 sería 1.8)
# 3. Crea una lista `pertenencias` con los 4 objetos más valiosos para ti (o con cuatro cosas tuyas que te gusten)
# 4. Crea otra lista `valor` con el valor en € por el que venderías cada uno de esos objetos. Pon los valores en el mismo orden que los objetos.
# 5. Crea una tupla `personas_cercanas` con los nombres de 3 personas por las que tengas mucho cariño o amistad o simplemente con 3 personas de tu familia.
# 6. Asigna a la variable `regalo` el tercer objeto de pertencias
# 7. Asigna a la variable `para` a la primera persona de las personas cercanas.
# 8. Haz una sub_lista que contenga sólo las dos primeras pertenencias, hazlo con un slicing de la lista inicial. Llamala `preferidas`
# 9. Entrega el `regalo` a `para`, es decir, imprime por pantalla de dos formas diferentes: "yo, tu_nombre, te regalo esto regalo a ti, nombre_persona_regalada" (usa las variables adecuadas y recuerda que tu nombre ya lo tienes en una variable si has seguido las instrucciones)

# %% [markdown]
# ### Ejercicio 1.2 (1 punto)
# Considerando las variables del ejercicio anterior y las que ya hayas creado antes:
#
# 1. Asigna a `cosas_ordenadas` la lista `pertenencias` ordenada alfabéticamente (ojo, `cosas_ordenadas` debe contener la lista ordenada).
# 2. Muestra `cosas_ordenadas` usando un print. [Se puntuará que además se haga cambiando el separador de la lista por ";" (esto es bonus +0.2)]
# 3. A partir de `valor`,  la lista de valores de pertenencias, crea otra lista `valor_ordenado` de forma que siga el orden de `cosas_ordenadas` (que el valor del primer elemento de cosas_ordenadas sea el primer elemento de valor_ordenado, etc). Hazlo "a mano".
# 4. Cambia, de alguna forma, el nombre  de la 3 persona por el de Jaime de manera que `personas_cercanas` siga siendo una tupla pero con el tercer elemento "Jaime"
# 5. Duplica la lista de objetos concatenando listas
# 6. Regálale dos objetos a Jaime, imprimiendo por pantalla “A ti Jaime te regalo: nombre del objeto”. Hazlo usando variables, no las cadenas directamente
# 7. Elimina esos dos objetos de la lista duplicada. Hazlo de dos formas diferentes.
# 8. Finalmente comprueba si puedes emplear los dos tickets para atracciones que te regala Jaime: (usa dos comparaciones booleanas)
# Ticket1 -> Tren del terror, altura minima: 1 metro 50, edad minima: 15
# Ticket2 -> Alicia en el pais de Oz, altura maxima: 1 metro 90, edad maxima: 35

# %% [markdown]
# ### Ejercicio 1.3 (1.5 puntos)
# 1. Crea un diccionario vacio
# 2. Añade un campo/clave `etapa de la vida`, dejalo vacio tipo string.
# 3. Añade un campo/clave `años`, dale un valor int, el que tu quieras.
# 4. Añade un campo/clave `pelicula favorita`, dale un valor vacio tipo string.
# 5. Añade un campo/clave `motivo`, dale un valor vacio tipo string.
# 6. Crea una lista vacía llamada `lista_peliculas`
# 7. Añade tres diccionarios a la lista con las siguientes etapas Infancia, Adolescencia, Juventud y los años, 10, 16, 25 (o tu edad actual :-) si es menor.
# 8. Completa los otros dos campos de cada diccionario.
# 9. Imprime por pantalla, las claves, los valores y los pares de clave y valor. Hazlo siguiendo el siguiente código ejemplo:
# ```python
# for pelicula in lista_peliculas:
#     codigo para imprimir las claves de cada pelicula, los valores y los pares clave y valor.
# ```

# %% [markdown]
# ## PARTE II. CONTROL DE FLUJOS [3.5 puntos, Bonus: hasta 3.5 puntos más]

# %% [markdown]
# **Solo tienes que hacer uno de los dos ejercicios (o el ejercicio 2.1 o el 2.2)** pero si haces los dos cuenta. Así que si te lías con la parte III quizá te compense hacer los dos ejercicios de esta parte.
# Por supuesto si haces los ejercicios de esta parte y la parte 3 todo se acumula.

# %% [markdown]
# ### Ejercicio 2.1

# %% [markdown]
# #### Parte I (3 puntos)
# Haz un programa que cumpla las siguientes instrucciones:
# 1. Pregunte una lista de números enteros al usuario (números separados por comas)
# 2. Pregunte por una de estas dos operaciones: multiplicar o sumar.
# 3. Si el usuario pide multiplicar, calcule la multiplicación de todos los elementos de la lista y divide el resultado por el úlitimo.
# 4. Si el usuario pide sumar, calcule la suma de los elementos sin utilizar bucles.
# 5. Presente el resultado por pantalla.

# %% [markdown]
# #### Parte II (0.5 puntos)
#
# 7. Completa el programa para que puedas repetir la operación tantas veces como quieras hasta que en vez del número a reemplazar introduzcas las palabra "exit" (sin las comillas)

# %% [markdown]
# ### EJercicio 2.2

# %% [markdown]
# #### Parte I (3 puntos)
# 1. Crea las siguientes listas:
# ```python
# escritoras = ["Toni Morrison","Dolores Redondo","Margaret Atwood","Gabriela Mistral","Alice Munro","Agatha Christie","Carmen Laforet"]
# nobel = [True, False, False, True, True, False, False]
# viva = [False, True, True, False, True, False, False]
# ```
#
# 2. Crea un programa que encuentre las ganadoras del premio nobel e imprima sus nombres ordenados alfabéticamente (considerando el nombre primero)
# 3. Crea un programa que encuentre las escritoras vivas de la lista e imprimas sus nombre ordenados anti-alfabéticamente (es decir inverso al alfabético y de nuvo considerando el nombre primero)
# 4. Crea un programa que encuentre las escritoras vivas que hayan ganado el premio nobel y las fallecidas que no y lo imprima por pantalla.

# %% [markdown]
# #### Parte II (0.5 puntos)
#
# 5. Modifica el programa del punto 2 para que el orden alfabético lo sea considerando el apellido primero.

# %% [markdown]
# ## PARTE III. FUNCIONES (y todo lo anterior) [4 + 1 Puntos]

# %% [markdown]
# ### Ejercicio 3 (4 puntos)

# %% [markdown]
# Uno de los sistemas criptográficos conocidos más antiguos es el denominado código César, atribuido a Julio César, aunque en realidad no es exactamente suyo. En general se denomina código César a todo sistema criptográfico que consiste en sustituir una letra por otra n posiciones anteriores o posteriores en el alfabeto. Así un código césar 3, susituiría la letra a por la letra d, la letra b por la letra e, etc. Llegados a las últimas letras sustituye estas volviendo al principio es decir la letra z pasaría a ser la c, la y la b y la x la a. Véase el diagrama siguiente:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Donde "casa" ha quedado convertido en "fdvd" y rampup en "udpsxs". Vamos a construirnos dos funciones una que cifre y otra que descifre:

# %% [markdown]
# Se pide:
# 1. Crear una lista (llamala `original`) con el alfabeto original tal y como viene representado en la figura (en la posicion 0 la a y en la últimza la z) (0.5 puntos)

# %%
original = []

# %% [markdown]
# 2. Crear una lista con el cifrado (llámala `cifrado`) tal y como aparece en la figura (en la posición 0 la d y en la última la c). Se pide hacerlo con un bucle for a partir de la lista anterior. Pero si no lo logras, para poder continuar con el ejercicio hazlo a mano. (0.5 puntos)

# %%
cifrado = []

# %% [markdown]
# 3. Crea con código, no a mano, un diccionario cifrador que tenga como claves las letras de la lista `original` y como valores las letras de la lista `cifrado`:
# ```python
# diccionario_cifrador = { "a": "d", ...., "z": "c"}
# ```
# Pista: Tendrás que recorrer las dos listas en paralelo usando un for y enumerate.
# (0.75 puntos)

# %% [markdown]
# 4. Crea una funcion `cifrado` que tenga como argumento una variable `plaintext` en la que pasarle una palabra y que haciendo uso del diccionario cifrador la convierta en una palabra cifrada, es decir sustituya todas las letras por sus letras cifradas, y la devuelva. Importante, convierte en minusculas plaintext antes de cifrarla. Recordatorio: Devolver en el contexto de las funciones es que haga return con el valor indicado. (1.75 punto)

# %% [markdown]
# 5. Cifra la frase:"Como te pille te mato Jaime". Puntuará extra usar un bucle. (0.5 puntos)

# %% [markdown]
# ### BONUS:
#
# Modifica `cifrado` para que admita un numero variable de palabras separadas por comas (es decir que cada palabra sea un argumento) y considere que hay un espacio entre cada palabra.Convierte "y si te cojo dos veces te remato" de una sola vez.
