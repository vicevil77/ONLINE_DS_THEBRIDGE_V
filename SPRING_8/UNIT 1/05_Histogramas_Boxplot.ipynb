# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Visualización con Matplotlib: Histogramas y diagramas de caja

# %% [markdown]
# Vamos a ver de forma sencilla como hacer los gráficos que nos generaban las funciones que empleamos en las visualizaciones analiticas del sprint anteior. En concreto, veremos los histogramas y los boxplots:

# %%
#%matplotlib inline
import matplotlib.pyplot as plt
import numpy as np



data = np.random.randn(1000)

# %% [markdown]
# ### Histogramas

# %% [markdown]
# Tan sencillo como:

# %%
plt.hist(data);

# %%
fig = plt.figure(figsize=(4.5,3))
ax = plt.axes()
ax.hist(data)
# Out:
# (array([  1.,   6.,  33.,  91., 233., 290., 213.,  89.,  37.,   7.]),
#  array([-3.7194647 , -3.04440987, -2.36935504, -1.69430021, -1.01924538,
#         -0.34419055,  0.33086428,  1.00591912,  1.68097395,  2.35602878,
#          3.03108361]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# La función ``hist()`` tiene muchas opciones para ajustar tanto el cálculo como la visualización; aquí tienes un ejemplo de un histograma más personalizado (en el que tocamos el número de columnas `bins`, la transparencia y el color):

# %%
plt.hist(data,
         bins=50,#numero de cajas qie conforman el histogramna
         alpha= 1,#trasnperencia
         color="steelblue");

# %% [markdown]
# La transparencia es particularmente interesante para comparar histogramas o mostrar dicha comparación (y aprovecho para enseñarte un truco para cuando tengas argumentos repetidos que poner en tus llamadas a función):

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(alpha = 0.3, bins = 20)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %% [markdown]
# Es también el momento de enseñarte a capturar los límites de esos bines:

# %%
fig = plt.figure()
ax = plt.axes()
limites = ax.hist(x1, alpha = 0.3, bins = 30)

# %% [markdown]
# Limites es una tupla en la que el primer valor son los conteos y el segundo los límites de las barras:

# %%
limites[0]
# Out:
# array([ 3.,  1.,  0.,  1.,  6., 13., 16., 14., 27., 45., 54., 55., 68.,
#        89., 86., 87., 90., 72., 66., 52., 44., 47., 20., 18.,  9.,  6.,
#         7.,  1.,  1.,  2.])

# %%
limites[1]
# Out:
# array([-2.64143573, -2.46692811, -2.2924205 , -2.11791289, -1.94340528,
#        -1.76889767, -1.59439006, -1.41988245, -1.24537484, -1.07086722,
#        -0.89635961, -0.721852  , -0.54734439, -0.37283678, -0.19832917,
#        -0.02382156,  0.15068606,  0.32519367,  0.49970128,  0.67420889,
#         0.8487165 ,  1.02322411,  1.19773172,  1.37223934,  1.54674695,
#         1.72125456,  1.89576217,  2.07026978,  2.24477739,  2.419285  ,
#         2.59379262])

# %% [markdown]
# ### Boxplots
#
# Los diagramas de caja eran esos diagramas en los que resumíamos las medidas de posición y añadíamos una posible formar de obtener valores anómalos, extremos o outliers. En forma de diagrama:

# %% [markdown]
# ```text
#      Q1-1.5IQR   Q1  mediana  Q3   Q3+1.5IQR
#                   |-----:-----|
#   o      |--------|     :     |--------|    o  o
#                   |-----:-----|
# flier             <----------->            fliers/outlier
#                        IQR
#
# ```

# %% [markdown]
# Donde IQR es el rango intercuartilico (la diferencia entre el valor de Q3 o tercer cuartil o percentil-75 y el valor de Q1 o primer cuartil, o percentil-25)

# %% [markdown]
# En matplotlib:

# %%
plt.boxplot(data, whis=1.5)# whis establece el limite de los bigotes
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e411f24550>,
#   <matplotlib.lines.Line2D at 0x1e411f247f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e411f24a90>,
#   <matplotlib.lines.Line2D at 0x1e411f24d30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e411f242b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e411f24fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e411f25270>],
#  'means': []}

# %% [markdown]
# En el caso de matplotlib empleamos por defecto diagramas de caja verticales. Pero podemos cambiarlo:

# %%
plt.boxplot(data,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e4121900a0>,
#   <matplotlib.lines.Line2D at 0x1e412190340>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e4121905e0>,
#   <matplotlib.lines.Line2D at 0x1e412190880>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e41202fdc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e412190b20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e412190dc0>],
#  'means': []}

# %% [markdown]
# Y podemos mostrar varios juntos:

# %%
plt.boxplot([x1,x2,x3])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e414357490>,
#   <matplotlib.lines.Line2D at 0x1e414357730>,
#   <matplotlib.lines.Line2D at 0x1e41437c730>,
#   <matplotlib.lines.Line2D at 0x1e41437c9d0>,
#   <matplotlib.lines.Line2D at 0x1e41437d990>,
#   <matplotlib.lines.Line2D at 0x1e41437dc30>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e4143579d0>,
#   <matplotlib.lines.Line2D at 0x1e414357c70>,
#   <matplotlib.lines.Line2D at 0x1e41437cc70>,
#   <matplotlib.lines.Line2D at 0x1e41437cf10>,
#   <matplotlib.lines.Line2D at 0x1e41437ded0>,
#   <matplotlib.lines.Line2D at 0x1e41437e170>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e4143571f0>,
#   <matplotlib.lines.Line2D at 0x1e41437c490>,
#   <matplotlib.lines.Line2D at 0x1e41437d6f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e414357f10>,
#   <matplotlib.lines.Line2D at 0x1e41437d1b0>,
#   <matplotlib.lines.Line2D at 0x1e41437e410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e41437c1f0>,
#   <matplotlib.lines.Line2D at 0x1e41437d450>,
#   <matplotlib.lines.Line2D at 0x1e41437e6b0>],
#  'means': []}
