# %% [markdown]
# REG_LOG

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# REG_LOG_HIPER

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# REG_LOG_BALANCED

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# KNC

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# KNC_HIPER

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# KNC_SMOTE

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# DTC

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# DTC_HIPER

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# DTC_SMOTE

# %% [markdown]
# ![image.png](attachment:image.png)
