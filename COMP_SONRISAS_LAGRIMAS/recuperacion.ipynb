# %%
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.applications import VGG19,VGG16, EfficientNetB0, EfficientNetB1, EfficientNetB2, EfficientNetB3, EfficientNetB4, resnet_v2, ResNet50, ResNet101, ResNet152, ResNet50V2 
from tensorflow.keras.applications import ResNet101V2, ResNet152V2, InceptionV3, InceptionResNetV2, Xception, MobileNet, MobileNetV2, DenseNet121, DenseNet169, DenseNet201, NASNetLarge, NASNetMobile

# %%
# Cargar el modelo
model = load_model('modelos/1modelo_descongelado_inventado_imagenes_res.h5')

"""for layer in model.layers:
    print(layer.get_weights())"""
    
# Imprimir un resumen de la arquitectura del modelo
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  mobilenetv2_1.00_160 (Funct  (None, 5, 5, 1280)       2257984
#  ional)
#
#  flatten_1 (Flatten)         (None, 32000)             0
#
#  dense_2 (Dense)             (None, 256)               8192256
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 1)                 129
#
# ...
# Total params: 10,483,265
# Trainable params: 10,449,153
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
modelo_gan_mvnet=MobileNetV2(weights='imagenet', include_top=False, input_shape=(160, 160, 3))

#for layer in modelo_gan_mvnet.layers[:-20]:
   # layer.trainable = True
modelo_gan_mvnet.trainable=True

ultima_capa = modelo_gan_mvnet.output
x= Flatten()(ultima_capa)
x = Dense(256, activation='relu')(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)
out = Dense(1, activation='sigmoid')(x)

modelo_gan_mvnet = Model(modelo_gan_mvnet.input, out)

modelo_gan_mvnet.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

modelo_gan_mvnet.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 160, 160, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 80, 80, 32)   864         ['input_5[0][0]']
#
#  bn_Conv1 (BatchNormalization)  (None, 80, 80, 32)   128         ['Conv1[0][0]']
#
#  Conv1_relu (ReLU)              (None, 80, 80, 32)   0           ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (Depth  (None, 80, 80, 32)  288         ['Conv1_relu[0][0]']
#  wiseConv2D)
#
#  expanded_conv_depthwise_BN (Ba  (None, 80, 80, 32)  128         ['expanded_conv_depthwise[0][0]']
#  tchNormalization)
#
#  expanded_conv_depthwise_relu (  (None, 80, 80, 32)  0           ['expanded_conv_depthwise_BN[0][0
#  ReLU)                                                           ]']
#
# ...
